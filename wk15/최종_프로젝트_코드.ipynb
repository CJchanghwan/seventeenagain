# %% [markdown]
# # 필요 라이브러리 호출

# %%
# !pip install segmentation_models_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segmentation_models_pytorch
#   Downloading segmentation_models_pytorch-0.2.1-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 4.7 MB/s
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 41.3 MB/s
# Collecting pretrainedmodels==0.7.4
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 8.2 MB/s
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from segmentation_models_pytorch) (0.12.0+cu113)
# Collecting efficientnet-pytorch==0.6.3
#   Downloading efficientnet_pytorch-0.6.3.tar.gz (16 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.6.3->segmentation_models_pytorch) (1.11.0+cu113)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pretrainedmodels==0.7.4->segmentation_models_pytorch) (4.64.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.6.3->segmentation_models_pytorch) (4.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation_models_pytorch) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation_models_pytorch) (2.23.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation_models_pytorch) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation_models_pytorch) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation_models_pytorch) (2.10)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-py3-none-any.whl size=12421 sha256=6c2b2bf09271edfa5a4951001ea0dc03a8ba2d9a1b3934bcaa1db0c26bd3ca62
#   Stored in directory: /root/.cache/pip/wheels/90/6b/0c/f0ad36d00310e65390b0d4c9218ae6250ac579c92540c9097a
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60965 sha256=6ce7e3e8f0cdff137c3ab45eb6887eaf9d0ce62e222c95092a63bcf58858b3d7
#   Stored in directory: /root/.cache/pip/wheels/ed/27/e8/9543d42de2740d3544db96aefef63bda3f2c1761b3334f4873
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.6.3 munch-2.5.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.2.1 timm-0.4.12

# %%
import os, tqdm, math, random, argparse

import numpy as np
import pandas as pd

from glob import glob
from PIL import Image
from matplotlib import pyplot as plt

import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torchvision.transforms.functional as TF
from torch.utils.data import DataLoader, Dataset

from tqdm.notebook import tqdm

import segmentation_models_pytorch as smp
#from pytorch_msssim import MS_SSIM

import cv2
import random

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
device = torch.device(device)
print(device)

#device는 학습 환경을 cpu로 할 것인지 아니면 gpu로 할것인지 에 대한 변수이다.
# torch.cuda.is_available()는 말 그대로 cuda(gpu)을 사용할 수 있으면 사용하겠다는 의미
# Out:
# cuda:0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 빛번짐 최소화 인공지능 데이터 수집
#
# Dacon : https://dacon.io/competitions/official/235746/data
#
# DACON에서 가져온 같은장소에서 빛번짐이 존재하는 이미지 데이터 622개와 빛 번짐이 없는 이미지 데이터 622개로 이루어진 데이터셋을 제공해줘서 이 데이터셋을 다운로드.
#
#  모두 비정형 데이터 이며 이미지 크기는 3264*2448와 1632*1224 두가지의 PNG형식의 비정형 데이터임.
#
#  개발 시 622개의 데이터셋을 학습용으로 562개 검증용으로 60개로 사용하였음.
# -빛이 번져있는 사진을 인공지능에 넣었을 때 생성되는 빛이 줄이든 사진이 이미 준비해둔 빛이 안번져있는 사진과 시각 적으로 비교해서 얼마나 잘 줄어들었는지 확인하기위함.
#
#  DACON에서 다운받는 데이터로만 진행했기 때문에 위의 과정을 거치고 같은 장소의 빛이 번져있는 사진과 안번져있는 사진을 구할 수 있으면 파일 형식과 사진 개수는 무관함.

# %% [markdown]
# # directory 확인

# %%
cd '/content/drive/MyDrive'
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
#  후방/                                '빛번짐 최소화 시연영상.mp4'
#  전방1/                                night/
# '11주차 캡스톤 발표자료(05.23).pptx'   night_test/
#  전방2/                                night_test1/
#  acc/                                  night_test.zip
#  black/                               'night time road images'
#  chgo.zip                             'night time road images (1)'/
# 'Colab Notebooks'/                     resnet/
#  CycleGAN.ipynb                        result/
#  day/                                  test/
#  db4_report_20174249_고창환.7z         testB/
#  db4_report_20174249_고창환.zip        test.csv
#  densenet/                             train/
#  efficientnet/                         train.csv
# '최종 프로젝트 코드.ipynb'             Untitled0.ipynb
#  label/                               '빛 번짐 결과(vaildation).mp4'
#  mobilnet/                             weight/
# '코랩 이용법(구현 환경).mp4'           밤.zip
# '데이터 수집 방법(빛번짐).mp4'         낮.zip

# %%
cd '/content/drive/MyDrive/train'
# Out:
# /content/drive/MyDrive/train

# %%
ls
# Out:
# train_input_10000.png  train_input_10415.png  train_label_10208.png
# train_input_10001.png  train_input_10416.png  train_label_10209.png
# train_input_10002.png  train_input_10417.png  train_label_10210.png
# train_input_10003.png  train_input_10418.png  train_label_10211.png
# train_input_10004.png  train_input_10419.png  train_label_10212.png
# train_input_10005.png  train_input_10420.png  train_label_10213.png
# train_input_10006.png  train_input_10421.png  train_label_10214.png
# train_input_10007.png  train_input_10422.png  train_label_10215.png
# train_input_10008.png  train_input_10423.png  train_label_10216.png
# train_input_10009.png  train_input_10424.png  train_label_10217.png
# train_input_10010.png  train_input_10425.png  train_label_10218.png
# train_input_10011.png  train_input_10426.png  train_label_10219.png
# train_input_10012.png  train_input_10427.png  train_label_10220.png
# train_input_10013.png  train_input_10428.png  train_label_10221.png
# train_input_10014.png  train_input_10429.png  train_label_10222.png
# train_input_10015.png  train_input_10430.png  train_label_10223.png
# train_input_10016.png  train_input_10431.png  train_label_10224.png
# train_input_10017.png  train_input_10432.png  train_label_10225.png
# train_input_10018.png  train_input_10433.png  train_label_10226.png
# train_input_10019.png  train_input_10434.png  train_label_10227.png
# train_input_10020.png  train_input_10435.png  train_label_10228.png
# train_input_10021.png  train_input_10436.png  train_label_10229.png
# train_input_10022.png  train_input_10437.png  train_label_10230.png
# train_input_10023.png  train_input_10438.png  train_label_10231.png
# train_input_10024.png  train_input_10439.png  train_label_10232.png
# train_input_10025.png  train_input_10440.png  train_label_10233.png
# train_input_10026.png  train_input_10441.png  train_label_10234.png
# train_input_10027.png  train_input_10442.png  train_label_10235.png
# train_input_10028.png  train_input_10443.png  train_label_10236.png
# train_input_10029.png  train_input_10444.png  train_label_10237.png
# train_input_10030.png  train_input_10445.png  train_label_10238.png
# train_input_10031.png  train_input_10446.png  train_label_10239.png
# train_input_10032.png  train_input_10447.png  train_label_10240.png
# train_input_10033.png  train_input_10448.png  train_label_10241.png
# train_input_10034.png  train_input_10449.png  train_label_10242.png
# train_input_10035.png  train_input_10450.png  train_label_10243.png
# train_input_10036.png  train_input_10451.png  train_label_10244.png
# train_input_10037.png  train_input_10452.png  train_label_10245.png
# train_input_10038.png  train_input_10453.png  train_label_10246.png
# train_input_10039.png  train_input_10454.png  train_label_10247.png
# train_input_10040.png  train_input_10455.png  train_label_10248.png
# train_input_10041.png  train_input_10456.png  train_label_10249.png
# train_input_10042.png  train_input_10457.png  train_label_10250.png
# train_input_10043.png  train_input_10458.png  train_label_10251.png
# train_input_10044.png  train_input_10459.png  train_label_10252.png
# train_input_10045.png  train_input_10460.png  train_label_10253.png
# train_input_10046.png  train_input_10461.png  train_label_10254.png
# train_input_10047.png  train_input_10462.png  train_label_10255.png
# train_input_10048.png  train_input_10463.png  train_label_10256.png
# train_input_10049.png  train_input_10464.png  train_label_10257.png
# train_input_10050.png  train_input_10465.png  train_label_10258.png
# train_input_10051.png  train_input_10466.png  train_label_10259.png
# train_input_10052.png  train_input_10467.png  train_label_10260.png
# train_input_10053.png  train_input_10468.png  train_label_10261.png
# train_input_10054.png  train_input_10469.png  train_label_10262.png
# train_input_10055.png  train_input_10470.png  train_label_10263.png
# train_input_10056.png  train_input_10471.png  train_label_10264.png
# train_input_10057.png  train_input_10472.png  train_label_10265.png
# train_input_10058.png  train_input_10473.png  train_label_10266.png
# train_input_10059.png  train_input_10474.png  train_label_10267.png
# train_input_10060.png  train_input_10475.png  train_label_10268.png
# train_input_10061.png  train_input_10476.png  train_label_10269.png
# train_input_10062.png  train_input_10477.png  train_label_10270.png
# train_input_10063.png  train_input_10478.png  train_label_10271.png
# train_input_10064.png  train_input_10479.png  train_label_10272.png
# train_input_10065.png  train_input_10480.png  train_label_10273.png
# train_input_10066.png  train_input_10481.png  train_label_10274.png
# train_input_10067.png  train_input_10482.png  train_label_10275.png
# train_input_10068.png  train_input_10483.png  train_label_10276.png
# train_input_10069.png  train_input_10484.png  train_label_10277.png
# train_input_10070.png  train_input_10485.png  train_label_10278.png
# train_input_10071.png  train_input_10486.png  train_label_10279.png
# train_input_10072.png  train_input_10487.png  train_label_10280.png
# train_input_10073.png  train_input_10488.png  train_label_10281.png
# train_input_10074.png  train_input_10489.png  train_label_10282.png
# train_input_10075.png  train_input_10490.png  train_label_10283.png
# train_input_10076.png  train_input_10491.png  train_label_10284.png
# train_input_10077.png  train_input_10492.png  train_label_10285.png
# train_input_10078.png  train_input_10493.png  train_label_10286.png
# train_input_10079.png  train_input_10494.png  train_label_10287.png
# train_input_10080.png  train_input_10495.png  train_label_10288.png
# train_input_10081.png  train_input_10496.png  train_label_10289.png
# train_input_10082.png  train_input_10497.png  train_label_10290.png
# train_input_10083.png  train_input_10498.png  train_label_10291.png
# train_input_10084.png  train_input_10499.png  train_label_10292.png
# train_input_10085.png  train_input_10500.png  train_label_10293.png
# train_input_10086.png  train_input_10501.png  train_label_10294.png
# train_input_10087.png  train_input_10502.png  train_label_10295.png
# train_input_10088.png  train_input_10503.png  train_label_10296.png
# train_input_10089.png  train_input_10504.png  train_label_10297.png
# train_input_10090.png  train_input_10505.png  train_label_10298.png
# train_input_10091.png  train_input_10506.png  train_label_10299.png
# train_input_10092.png  train_input_10507.png  train_label_10300.png
# train_input_10093.png  train_input_10508.png  train_label_10301.png
# train_input_10094.png  train_input_10509.png  train_label_10302.png
# train_input_10095.png  train_input_10510.png  train_label_10303.png
# train_input_10096.png  train_input_10511.png  train_label_10304.png
# train_input_10097.png  train_input_10512.png  train_label_10305.png
# train_input_10098.png  train_input_10513.png  train_label_10306.png
# train_input_10099.png  train_input_10514.png  train_label_10307.png
# train_input_10100.png  train_input_10515.png  train_label_10308.png
# train_input_10101.png  train_input_10516.png  train_label_10309.png
# train_input_10102.png  train_input_10517.png  train_label_10310.png
# train_input_10103.png  train_input_10518.png  train_label_10311.png
# train_input_10104.png  train_input_10519.png  train_label_10312.png
# train_input_10105.png  train_input_10520.png  train_label_10313.png
# train_input_10106.png  train_input_10521.png  train_label_10314.png
# train_input_10107.png  train_input_10522.png  train_label_10315.png
# train_input_10108.png  train_input_10523.png  train_label_10316.png
# train_input_10109.png  train_input_10524.png  train_label_10317.png
# train_input_10110.png  train_input_10525.png  train_label_10318.png
# train_input_10111.png  train_input_10526.png  train_label_10319.png
# train_input_10112.png  train_input_10527.png  train_label_10320.png
# train_input_10113.png  train_input_10528.png  train_label_10321.png
# train_input_10114.png  train_input_10529.png  train_label_10322.png
# train_input_10115.png  train_input_10530.png  train_label_10323.png
# train_input_10116.png  train_input_10531.png  train_label_10324.png
# train_input_10117.png  train_input_10532.png  train_label_10325.png
# train_input_10118.png  train_input_10533.png  train_label_10326.png
# train_input_10119.png  train_input_10534.png  train_label_10327.png
# train_input_10120.png  train_input_10535.png  train_label_10328.png
# train_input_10121.png  train_input_10536.png  train_label_10329.png
# train_input_10122.png  train_input_10537.png  train_label_10330.png
# train_input_10123.png  train_input_10538.png  train_label_10331.png
# train_input_10124.png  train_input_10539.png  train_label_10332.png
# train_input_10125.png  train_input_10540.png  train_label_10333.png
# train_input_10126.png  train_input_10541.png  train_label_10334.png
# train_input_10127.png  train_input_10542.png  train_label_10335.png
# train_input_10128.png  train_input_10543.png  train_label_10336.png
# train_input_10129.png  train_input_10544.png  train_label_10337.png
# train_input_10130.png  train_input_10545.png  train_label_10338.png
# train_input_10131.png  train_input_10546.png  train_label_10339.png
# train_input_10132.png  train_input_10547.png  train_label_10340.png
# train_input_10133.png  train_input_10548.png  train_label_10341.png
# train_input_10134.png  train_input_10549.png  train_label_10342.png
# train_input_10135.png  train_input_10550.png  train_label_10343.png
# train_input_10136.png  train_input_10551.png  train_label_10344.png
# train_input_10137.png  train_input_10552.png  train_label_10345.png
# train_input_10138.png  train_input_10553.png  train_label_10346.png
# train_input_10139.png  train_input_10554.png  train_label_10347.png
# train_input_10140.png  train_input_10555.png  train_label_10348.png
# train_input_10141.png  train_input_10556.png  train_label_10349.png
# train_input_10142.png  train_input_10557.png  train_label_10350.png
# train_input_10143.png  train_input_10558.png  train_label_10351.png
# train_input_10144.png  train_input_10559.png  train_label_10352.png
# train_input_10145.png  train_input_10560.png  train_label_10353.png
# train_input_10146.png  train_input_10561.png  train_label_10354.png
# train_input_10147.png  train_input_10562.png  train_label_10355.png
# train_input_10148.png  train_input_10563.png  train_label_10356.png
# train_input_10149.png  train_input_10564.png  train_label_10357.png
# train_input_10150.png  train_input_10565.png  train_label_10358.png
# train_input_10151.png  train_input_10566.png  train_label_10359.png
# train_input_10152.png  train_input_10567.png  train_label_10360.png
# train_input_10153.png  train_input_10568.png  train_label_10361.png
# train_input_10154.png  train_input_10569.png  train_label_10362.png
# train_input_10155.png  train_input_10570.png  train_label_10363.png
# train_input_10156.png  train_input_10571.png  train_label_10364.png
# train_input_10157.png  train_input_10572.png  train_label_10365.png
# train_input_10158.png  train_input_10573.png  train_label_10366.png
# train_input_10159.png  train_input_10574.png  train_label_10367.png
# train_input_10160.png  train_input_10575.png  train_label_10368.png
# train_input_10161.png  train_input_10576.png  train_label_10369.png
# train_input_10162.png  train_input_10577.png  train_label_10370.png
# train_input_10163.png  train_input_10578.png  train_label_10371.png
# train_input_10164.png  train_input_10579.png  train_label_10372.png
# train_input_10165.png  train_input_10580.png  train_label_10373.png
# train_input_10166.png  train_input_10581.png  train_label_10374.png
# train_input_10167.png  train_input_10582.png  train_label_10375.png
# train_input_10168.png  train_input_10583.png  train_label_10376.png
# train_input_10169.png  train_input_10584.png  train_label_10377.png
# train_input_10170.png  train_input_10585.png  train_label_10378.png
# train_input_10171.png  train_input_10586.png  train_label_10379.png
# train_input_10172.png  train_input_10587.png  train_label_10380.png
# train_input_10173.png  train_input_10588.png  train_label_10381.png
# train_input_10174.png  train_input_10589.png  train_label_10382.png
# train_input_10175.png  train_input_10590.png  train_label_10383.png
# train_input_10176.png  train_input_10591.png  train_label_10384.png
# train_input_10177.png  train_input_10592.png  train_label_10385.png
# train_input_10178.png  train_input_10593.png  train_label_10386.png
# train_input_10179.png  train_input_10594.png  train_label_10387.png
# train_input_10180.png  train_input_10595.png  train_label_10388.png
# train_input_10181.png  train_input_10596.png  train_label_10389.png
# train_input_10182.png  train_input_10597.png  train_label_10390.png
# train_input_10183.png  train_input_10598.png  train_label_10391.png
# train_input_10184.png  train_input_10599.png  train_label_10392.png
# train_input_10185.png  train_input_10600.png  train_label_10393.png
# train_input_10186.png  train_input_10601.png  train_label_10394.png
# train_input_10187.png  train_input_10602.png  train_label_10395.png
# train_input_10188.png  train_input_10603.png  train_label_10396.png
# train_input_10189.png  train_input_10604.png  train_label_10397.png
# train_input_10190.png  train_input_10605.png  train_label_10398.png
# train_input_10191.png  train_input_10606.png  train_label_10399.png
# train_input_10192.png  train_input_10607.png  train_label_10400.png
# train_input_10193.png  train_input_10608.png  train_label_10401.png
# train_input_10194.png  train_input_10609.png  train_label_10402.png
# train_input_10195.png  train_input_10610.png  train_label_10403.png
# train_input_10196.png  train_input_10611.png  train_label_10404.png
# train_input_10197.png  train_input_10612.png  train_label_10405.png
# train_input_10198.png  train_input_10613.png  train_label_10406.png
# train_input_10199.png  train_input_10614.png  train_label_10407.png
# train_input_10200.png  train_input_10615.png  train_label_10408.png
# train_input_10201.png  train_input_10616.png  train_label_10409.png
# train_input_10202.png  train_input_10617.png  train_label_10410.png
# train_input_10203.png  train_input_10618.png  train_label_10411.png
# train_input_10204.png  train_input_10619.png  train_label_10412.png
# train_input_10205.png  train_input_10620.png  train_label_10413.png
# train_input_10206.png  train_input_10621.png  train_label_10414.png
# train_input_10207.png  train_label_10000.png  train_label_10415.png
# train_input_10208.png  train_label_10001.png  train_label_10416.png
# train_input_10209.png  train_label_10002.png  train_label_10417.png
# train_input_10210.png  train_label_10003.png  train_label_10418.png
# train_input_10211.png  train_label_10004.png  train_label_10419.png
# train_input_10212.png  train_label_10005.png  train_label_10420.png
# train_input_10213.png  train_label_10006.png  train_label_10421.png
# train_input_10214.png  train_label_10007.png  train_label_10422.png
# train_input_10215.png  train_label_10008.png  train_label_10423.png
# train_input_10216.png  train_label_10009.png  train_label_10424.png
# train_input_10217.png  train_label_10010.png  train_label_10425.png
# train_input_10218.png  train_label_10011.png  train_label_10426.png
# train_input_10219.png  train_label_10012.png  train_label_10427.png
# train_input_10220.png  train_label_10013.png  train_label_10428.png
# train_input_10221.png  train_label_10014.png  train_label_10429.png
# train_input_10222.png  train_label_10015.png  train_label_10430.png
# train_input_10223.png  train_label_10016.png  train_label_10431.png
# train_input_10224.png  train_label_10017.png  train_label_10432.png
# train_input_10225.png  train_label_10018.png  train_label_10433.png
# train_input_10226.png  train_label_10019.png  train_label_10434.png
# train_input_10227.png  train_label_10020.png  train_label_10435.png
# train_input_10228.png  train_label_10021.png  train_label_10436.png
# train_input_10229.png  train_label_10022.png  train_label_10437.png
# train_input_10230.png  train_label_10023.png  train_label_10438.png
# train_input_10231.png  train_label_10024.png  train_label_10439.png
# train_input_10232.png  train_label_10025.png  train_label_10440.png
# train_input_10233.png  train_label_10026.png  train_label_10441.png
# train_input_10234.png  train_label_10027.png  train_label_10442.png
# train_input_10235.png  train_label_10028.png  train_label_10443.png
# train_input_10236.png  train_label_10029.png  train_label_10444.png
# train_input_10237.png  train_label_10030.png  train_label_10445.png
# train_input_10238.png  train_label_10031.png  train_label_10446.png
# train_input_10239.png  train_label_10032.png  train_label_10447.png
# train_input_10240.png  train_label_10033.png  train_label_10448.png
# train_input_10241.png  train_label_10034.png  train_label_10449.png
# train_input_10242.png  train_label_10035.png  train_label_10450.png
# train_input_10243.png  train_label_10036.png  train_label_10451.png
# train_input_10244.png  train_label_10037.png  train_label_10452.png
# train_input_10245.png  train_label_10038.png  train_label_10453.png
# train_input_10246.png  train_label_10039.png  train_label_10454.png
# train_input_10247.png  train_label_10040.png  train_label_10455.png
# train_input_10248.png  train_label_10041.png  train_label_10456.png
# train_input_10249.png  train_label_10042.png  train_label_10457.png
# train_input_10250.png  train_label_10043.png  train_label_10458.png
# train_input_10251.png  train_label_10044.png  train_label_10459.png
# train_input_10252.png  train_label_10045.png  train_label_10460.png
# train_input_10253.png  train_label_10046.png  train_label_10461.png
# train_input_10254.png  train_label_10047.png  train_label_10462.png
# train_input_10255.png  train_label_10048.png  train_label_10463.png
# train_input_10256.png  train_label_10049.png  train_label_10464.png
# train_input_10257.png  train_label_10050.png  train_label_10465.png
# train_input_10258.png  train_label_10051.png  train_label_10466.png
# train_input_10259.png  train_label_10052.png  train_label_10467.png
# train_input_10260.png  train_label_10053.png  train_label_10468.png
# train_input_10261.png  train_label_10054.png  train_label_10469.png
# train_input_10262.png  train_label_10055.png  train_label_10470.png
# train_input_10263.png  train_label_10056.png  train_label_10471.png
# train_input_10264.png  train_label_10057.png  train_label_10472.png
# train_input_10265.png  train_label_10058.png  train_label_10473.png
# train_input_10266.png  train_label_10059.png  train_label_10474.png
# train_input_10267.png  train_label_10060.png  train_label_10475.png
# train_input_10268.png  train_label_10061.png  train_label_10476.png
# train_input_10269.png  train_label_10062.png  train_label_10477.png
# train_input_10270.png  train_label_10063.png  train_label_10478.png
# train_input_10271.png  train_label_10064.png  train_label_10479.png
# train_input_10272.png  train_label_10065.png  train_label_10480.png
# train_input_10273.png  train_label_10066.png  train_label_10481.png
# train_input_10274.png  train_label_10067.png  train_label_10482.png
# train_input_10275.png  train_label_10068.png  train_label_10483.png
# train_input_10276.png  train_label_10069.png  train_label_10484.png
# train_input_10277.png  train_label_10070.png  train_label_10485.png
# train_input_10278.png  train_label_10071.png  train_label_10486.png
# train_input_10279.png  train_label_10072.png  train_label_10487.png
# train_input_10280.png  train_label_10073.png  train_label_10488.png
# train_input_10281.png  train_label_10074.png  train_label_10489.png
# train_input_10282.png  train_label_10075.png  train_label_10490.png
# train_input_10283.png  train_label_10076.png  train_label_10491.png
# train_input_10284.png  train_label_10077.png  train_label_10492.png
# train_input_10285.png  train_label_10078.png  train_label_10493.png
# train_input_10286.png  train_label_10079.png  train_label_10494.png
# train_input_10287.png  train_label_10080.png  train_label_10495.png
# train_input_10288.png  train_label_10081.png  train_label_10496.png
# train_input_10289.png  train_label_10082.png  train_label_10497.png
# train_input_10290.png  train_label_10083.png  train_label_10498.png
# train_input_10291.png  train_label_10084.png  train_label_10499.png
# train_input_10292.png  train_label_10085.png  train_label_10500.png
# train_input_10293.png  train_label_10086.png  train_label_10501.png
# train_input_10294.png  train_label_10087.png  train_label_10502.png
# train_input_10295.png  train_label_10088.png  train_label_10503.png
# train_input_10296.png  train_label_10089.png  train_label_10504.png
# train_input_10297.png  train_label_10090.png  train_label_10505.png
# train_input_10298.png  train_label_10091.png  train_label_10506.png
# train_input_10299.png  train_label_10092.png  train_label_10507.png
# train_input_10300.png  train_label_10093.png  train_label_10508.png
# train_input_10301.png  train_label_10094.png  train_label_10509.png
# train_input_10302.png  train_label_10095.png  train_label_10510.png
# train_input_10303.png  train_label_10096.png  train_label_10511.png
# train_input_10304.png  train_label_10097.png  train_label_10512.png
# train_input_10305.png  train_label_10098.png  train_label_10513.png
# train_input_10306.png  train_label_10099.png  train_label_10514.png
# train_input_10307.png  train_label_10100.png  train_label_10515.png
# train_input_10308.png  train_label_10101.png  train_label_10516.png
# train_input_10309.png  train_label_10102.png  train_label_10517.png
# train_input_10310.png  train_label_10103.png  train_label_10518.png
# train_input_10311.png  train_label_10104.png  train_label_10519.png
# train_input_10312.png  train_label_10105.png  train_label_10520.png
# train_input_10313.png  train_label_10106.png  train_label_10521.png
# train_input_10314.png  train_label_10107.png  train_label_10522.png
# train_input_10315.png  train_label_10108.png  train_label_10523.png
# train_input_10316.png  train_label_10109.png  train_label_10524.png
# train_input_10317.png  train_label_10110.png  train_label_10525.png
# train_input_10318.png  train_label_10111.png  train_label_10526.png
# train_input_10319.png  train_label_10112.png  train_label_10527.png
# train_input_10320.png  train_label_10113.png  train_label_10528.png
# train_input_10321.png  train_label_10114.png  train_label_10529.png
# train_input_10322.png  train_label_10115.png  train_label_10530.png
# train_input_10323.png  train_label_10116.png  train_label_10531.png
# train_input_10324.png  train_label_10117.png  train_label_10532.png
# train_input_10325.png  train_label_10118.png  train_label_10533.png
# train_input_10326.png  train_label_10119.png  train_label_10534.png
# train_input_10327.png  train_label_10120.png  train_label_10535.png
# train_input_10328.png  train_label_10121.png  train_label_10536.png
# train_input_10329.png  train_label_10122.png  train_label_10537.png
# train_input_10330.png  train_label_10123.png  train_label_10538.png
# train_input_10331.png  train_label_10124.png  train_label_10539.png
# train_input_10332.png  train_label_10125.png  train_label_10540.png
# train_input_10333.png  train_label_10126.png  train_label_10541.png
# train_input_10334.png  train_label_10127.png  train_label_10542.png
# train_input_10335.png  train_label_10128.png  train_label_10543.png
# train_input_10336.png  train_label_10129.png  train_label_10544.png
# train_input_10337.png  train_label_10130.png  train_label_10545.png
# train_input_10338.png  train_label_10131.png  train_label_10546.png
# train_input_10339.png  train_label_10132.png  train_label_10547.png
# train_input_10340.png  train_label_10133.png  train_label_10548.png
# train_input_10341.png  train_label_10134.png  train_label_10549.png
# train_input_10342.png  train_label_10135.png  train_label_10550.png
# train_input_10343.png  train_label_10136.png  train_label_10551.png
# train_input_10344.png  train_label_10137.png  train_label_10552.png
# train_input_10345.png  train_label_10138.png  train_label_10553.png
# train_input_10346.png  train_label_10139.png  train_label_10554.png
# train_input_10347.png  train_label_10140.png  train_label_10555.png
# train_input_10348.png  train_label_10141.png  train_label_10556.png
# train_input_10349.png  train_label_10142.png  train_label_10557.png
# train_input_10350.png  train_label_10143.png  train_label_10558.png
# train_input_10351.png  train_label_10144.png  train_label_10559.png
# train_input_10352.png  train_label_10145.png  train_label_10560.png
# train_input_10353.png  train_label_10146.png  train_label_10561.png
# train_input_10354.png  train_label_10147.png  train_label_10562.png
# train_input_10355.png  train_label_10148.png  train_label_10563.png
# train_input_10356.png  train_label_10149.png  train_label_10564.png
# train_input_10357.png  train_label_10150.png  train_label_10565.png
# train_input_10358.png  train_label_10151.png  train_label_10566.png
# train_input_10359.png  train_label_10152.png  train_label_10567.png
# train_input_10360.png  train_label_10153.png  train_label_10568.png
# train_input_10361.png  train_label_10154.png  train_label_10569.png
# train_input_10362.png  train_label_10155.png  train_label_10570.png
# train_input_10363.png  train_label_10156.png  train_label_10571.png
# train_input_10364.png  train_label_10157.png  train_label_10572.png
# train_input_10365.png  train_label_10158.png  train_label_10573.png
# train_input_10366.png  train_label_10159.png  train_label_10574.png
# train_input_10367.png  train_label_10160.png  train_label_10575.png
# train_input_10368.png  train_label_10161.png  train_label_10576.png
# train_input_10369.png  train_label_10162.png  train_label_10577.png
# train_input_10370.png  train_label_10163.png  train_label_10578.png
# train_input_10371.png  train_label_10164.png  train_label_10579.png
# train_input_10372.png  train_label_10165.png  train_label_10580.png
# train_input_10373.png  train_label_10166.png  train_label_10581.png
# train_input_10374.png  train_label_10167.png  train_label_10582.png
# train_input_10375.png  train_label_10168.png  train_label_10583.png
# train_input_10376.png  train_label_10169.png  train_label_10584.png
# train_input_10377.png  train_label_10170.png  train_label_10585.png
# train_input_10378.png  train_label_10171.png  train_label_10586.png
# train_input_10379.png  train_label_10172.png  train_label_10587.png
# train_input_10380.png  train_label_10173.png  train_label_10588.png
# train_input_10381.png  train_label_10174.png  train_label_10589.png
# train_input_10382.png  train_label_10175.png  train_label_10590.png
# train_input_10383.png  train_label_10176.png  train_label_10591.png
# train_input_10384.png  train_label_10177.png  train_label_10592.png
# train_input_10385.png  train_label_10178.png  train_label_10593.png
# train_input_10386.png  train_label_10179.png  train_label_10594.png
# train_input_10387.png  train_label_10180.png  train_label_10595.png
# train_input_10388.png  train_label_10181.png  train_label_10596.png
# train_input_10389.png  train_label_10182.png  train_label_10597.png
# train_input_10390.png  train_label_10183.png  train_label_10598.png
# train_input_10391.png  train_label_10184.png  train_label_10599.png
# train_input_10392.png  train_label_10185.png  train_label_10600.png
# train_input_10393.png  train_label_10186.png  train_label_10601.png
# train_input_10394.png  train_label_10187.png  train_label_10602.png
# train_input_10395.png  train_label_10188.png  train_label_10603.png
# train_input_10396.png  train_label_10189.png  train_label_10604.png
# train_input_10397.png  train_label_10190.png  train_label_10605.png
# train_input_10398.png  train_label_10191.png  train_label_10606.png
# train_input_10399.png  train_label_10192.png  train_label_10607.png
# train_input_10400.png  train_label_10193.png  train_label_10608.png
# train_input_10401.png  train_label_10194.png  train_label_10609.png
# train_input_10402.png  train_label_10195.png  train_label_10610.png
# train_input_10403.png  train_label_10196.png  train_label_10611.png
# train_input_10404.png  train_label_10197.png  train_label_10612.png
# train_input_10405.png  train_label_10198.png  train_label_10613.png
# train_input_10406.png  train_label_10199.png  train_label_10614.png
# train_input_10407.png  train_label_10200.png  train_label_10615.png
# train_input_10408.png  train_label_10201.png  train_label_10616.png
# train_input_10409.png  train_label_10202.png  train_label_10617.png
# train_input_10410.png  train_label_10203.png  train_label_10618.png
# train_input_10411.png  train_label_10204.png  train_label_10619.png
# train_input_10412.png  train_label_10205.png  train_label_10620.png
# train_input_10413.png  train_label_10206.png  train_label_10621.png
# train_input_10414.png  train_label_10207.png

# %%
cd '/content/drive/'
# Out:
# /content/drive

# %%
train_csv = pd.read_csv('MyDrive/train.csv')
test_csv = pd.read_csv('MyDrive/test.csv')

# %%
train_csv.head()
# Out:
#    img_id              input_img              label_img
# 0   10000  train_input_10000.png  train_label_10000.png
# 1   10001  train_input_10001.png  train_label_10001.png
# 2   10002  train_input_10002.png  train_label_10002.png
# 3   10003  train_input_10003.png  train_label_10003.png
# 4   10004  train_input_10004.png  train_label_10004.png

# %%
test_csv.head()
# Out:
#    img_id             input_img submission_name
# 0   20000  test_input_20000.png  test_20000.png
# 1   20001  test_input_20001.png  test_20001.png
# 2   20002  test_input_20002.png  test_20002.png
# 3   20003  test_input_20003.png  test_20003.png
# 4   20004  test_input_20004.png  test_20004.png

# %%
train_all_input_files = 'MyDrive/train/'+train_csv['input_img']
train_all_label_files = 'MyDrive/label/'+train_csv['label_img']
test_all_input_files = 'MyDrive/test/'+test_csv['input_img']

# %% [markdown]
# # 학습 데이터와 검증 데이터를 분리

# %%
train_input_files = train_all_input_files[60:].to_numpy()
train_label_files = train_all_label_files[60:].to_numpy()

# %%
vaild_input_files = train_all_input_files[:60].to_numpy()
vaild_label_files = train_all_label_files[:60].to_numpy()

# %%
train_input_files
# Out:
# array(['MyDrive/train/train_input_10060.png',
#        'MyDrive/train/train_input_10061.png',
#        'MyDrive/train/train_input_10062.png',
#        'MyDrive/train/train_input_10063.png',
#        'MyDrive/train/train_input_10064.png',
#        'MyDrive/train/train_input_10065.png',
#        'MyDrive/train/train_input_10066.png',
#        'MyDrive/train/train_input_10067.png',
#        'MyDrive/train/train_input_10068.png',
#        'MyDrive/train/train_input_10069.png',
#        'MyDrive/train/train_input_10070.png',
#        'MyDrive/train/train_input_10071.png',
#        'MyDrive/train/train_input_10072.png',
#        'MyDrive/train/train_input_10073.png',
#        'MyDrive/train/train_input_10074.png',
#        'MyDrive/train/train_input_10075.png',
#        'MyDrive/train/train_input_10076.png',
#        'MyDrive/train/train_input_10077.png',
#        'MyDrive/train/train_input_10078.png',
#        'MyDrive/train/train_input_10079.png',
#        'MyDrive/train/train_input_10080.png',
#        'MyDrive/train/train_input_10081.png',
#        'MyDrive/train/train_input_10082.png',
#        'MyDrive/train/train_input_10083.png',
#        'MyDrive/train/train_input_10084.png',
#        'MyDrive/train/train_input_10085.png',
#        'MyDrive/train/train_input_10086.png',
#        'MyDrive/train/train_input_10087.png',
#        'MyDrive/train/train_input_10088.png',
#        'MyDrive/train/train_input_10089.png',
#        'MyDrive/train/train_input_10090.png',
#        'MyDrive/train/train_input_10091.png',
#        'MyDrive/train/train_input_10092.png',
#        'MyDrive/train/train_input_10093.png',
#        'MyDrive/train/train_input_10094.png',
#        'MyDrive/train/train_input_10095.png',
#        'MyDrive/train/train_input_10096.png',
#        'MyDrive/train/train_input_10097.png',
#        'MyDrive/train/train_input_10098.png',
#        'MyDrive/train/train_input_10099.png',
#        'MyDrive/train/train_input_10100.png',
#        'MyDrive/train/train_input_10101.png',
#        'MyDrive/train/train_input_10102.png',
#        'MyDrive/train/train_input_10103.png',
#        'MyDrive/train/train_input_10104.png',
#        'MyDrive/train/train_input_10105.png',
#        'MyDrive/train/train_input_10106.png',
#        'MyDrive/train/train_input_10107.png',
#        'MyDrive/train/train_input_10108.png',
#        'MyDrive/train/train_input_10109.png',
#        'MyDrive/train/train_input_10110.png',
#        'MyDrive/train/train_input_10111.png',
#        'MyDrive/train/train_input_10112.png',
#        'MyDrive/train/train_input_10113.png',
#        'MyDrive/train/train_input_10114.png',
#        'MyDrive/train/train_input_10115.png',
#        'MyDrive/train/train_input_10116.png',
#        'MyDrive/train/train_input_10117.png',
#        'MyDrive/train/train_input_10118.png',
#        'MyDrive/train/train_input_10119.png',
#        'MyDrive/train/train_input_10120.png',
#        'MyDrive/train/train_input_10121.png',
#        'MyDrive/train/train_input_10122.png',
#        'MyDrive/train/train_input_10123.png',
#        'MyDrive/train/train_input_10124.png',
#        'MyDrive/train/train_input_10125.png',
#        'MyDrive/train/train_input_10126.png',
#        'MyDrive/train/train_input_10127.png',
#        'MyDrive/train/train_input_10128.png',
#        'MyDrive/train/train_input_10129.png',
#        'MyDrive/train/train_input_10130.png',
#        'MyDrive/train/train_input_10131.png',
#        'MyDrive/train/train_input_10132.png',
#        'MyDrive/train/train_input_10133.png',
#        'MyDrive/train/train_input_10134.png',
#        'MyDrive/train/train_input_10135.png',
#        'MyDrive/train/train_input_10136.png',
#        'MyDrive/train/train_input_10137.png',
#        'MyDrive/train/train_input_10138.png',
#        'MyDrive/train/train_input_10139.png',
#        'MyDrive/train/train_input_10140.png',
#        'MyDrive/train/train_input_10141.png',
#        'MyDrive/train/train_input_10142.png',
#        'MyDrive/train/train_input_10143.png',
#        'MyDrive/train/train_input_10144.png',
#        'MyDrive/train/train_input_10145.png',
#        'MyDrive/train/train_input_10146.png',
#        'MyDrive/train/train_input_10147.png',
#        'MyDrive/train/train_input_10148.png',
#        'MyDrive/train/train_input_10149.png',
#        'MyDrive/train/train_input_10150.png',
#        'MyDrive/train/train_input_10151.png',
#        'MyDrive/train/train_input_10152.png',
#        'MyDrive/train/train_input_10153.png',
#        'MyDrive/train/train_input_10154.png',
#        'MyDrive/train/train_input_10155.png',
#        'MyDrive/train/train_input_10156.png',
#        'MyDrive/train/train_input_10157.png',
#        'MyDrive/train/train_input_10158.png',
#        'MyDrive/train/train_input_10159.png',
#        'MyDrive/train/train_input_10160.png',
#        'MyDrive/train/train_input_10161.png',
#        'MyDrive/train/train_input_10162.png',
#        'MyDrive/train/train_input_10163.png',
#        'MyDrive/train/train_input_10164.png',
#        'MyDrive/train/train_input_10165.png',
#        'MyDrive/train/train_input_10166.png',
#        'MyDrive/train/train_input_10167.png',
#        'MyDrive/train/train_input_10168.png',
#        'MyDrive/train/train_input_10169.png',
#        'MyDrive/train/train_input_10170.png',
#        'MyDrive/train/train_input_10171.png',
#        'MyDrive/train/train_input_10172.png',
#        'MyDrive/train/train_input_10173.png',
#        'MyDrive/train/train_input_10174.png',
#        'MyDrive/train/train_input_10175.png',
#        'MyDrive/train/train_input_10176.png',
#        'MyDrive/train/train_input_10177.png',
#        'MyDrive/train/train_input_10178.png',
#        'MyDrive/train/train_input_10179.png',
#        'MyDrive/train/train_input_10180.png',
#        'MyDrive/train/train_input_10181.png',
#        'MyDrive/train/train_input_10182.png',
#        'MyDrive/train/train_input_10183.png',
#        'MyDrive/train/train_input_10184.png',
#        'MyDrive/train/train_input_10185.png',
#        'MyDrive/train/train_input_10186.png',
#        'MyDrive/train/train_input_10187.png',
#        'MyDrive/train/train_input_10188.png',
#        'MyDrive/train/train_input_10189.png',
#        'MyDrive/train/train_input_10190.png',
#        'MyDrive/train/train_input_10191.png',
#        'MyDrive/train/train_input_10192.png',
#        'MyDrive/train/train_input_10193.png',
#        'MyDrive/train/train_input_10194.png',
#        'MyDrive/train/train_input_10195.png',
#        'MyDrive/train/train_input_10196.png',
#        'MyDrive/train/train_input_10197.png',
#        'MyDrive/train/train_input_10198.png',
#        'MyDrive/train/train_input_10199.png',
#        'MyDrive/train/train_input_10200.png',
#        'MyDrive/train/train_input_10201.png',
#        'MyDrive/train/train_input_10202.png',
#        'MyDrive/train/train_input_10203.png',
#        'MyDrive/train/train_input_10204.png',
#        'MyDrive/train/train_input_10205.png',
#        'MyDrive/train/train_input_10206.png',
#        'MyDrive/train/train_input_10207.png',
#        'MyDrive/train/train_input_10208.png',
#        'MyDrive/train/train_input_10209.png',
#        'MyDrive/train/train_input_10210.png',
#        'MyDrive/train/train_input_10211.png',
#        'MyDrive/train/train_input_10212.png',
#        'MyDrive/train/train_input_10213.png',
#        'MyDrive/train/train_input_10214.png',
#        'MyDrive/train/train_input_10215.png',
#        'MyDrive/train/train_input_10216.png',
#        'MyDrive/train/train_input_10217.png',
#        'MyDrive/train/train_input_10218.png',
#        'MyDrive/train/train_input_10219.png',
#        'MyDrive/train/train_input_10220.png',
#        'MyDrive/train/train_input_10221.png',
#        'MyDrive/train/train_input_10222.png',
#        'MyDrive/train/train_input_10223.png',
#        'MyDrive/train/train_input_10224.png',
#        'MyDrive/train/train_input_10225.png',
#        'MyDrive/train/train_input_10226.png',
#        'MyDrive/train/train_input_10227.png',
#        'MyDrive/train/train_input_10228.png',
#        'MyDrive/train/train_input_10229.png',
#        'MyDrive/train/train_input_10230.png',
#        'MyDrive/train/train_input_10231.png',
#        'MyDrive/train/train_input_10232.png',
#        'MyDrive/train/train_input_10233.png',
#        'MyDrive/train/train_input_10234.png',
#        'MyDrive/train/train_input_10235.png',
#        'MyDrive/train/train_input_10236.png',
#        'MyDrive/train/train_input_10237.png',
#        'MyDrive/train/train_input_10238.png',
#        'MyDrive/train/train_input_10239.png',
#        'MyDrive/train/train_input_10240.png',
#        'MyDrive/train/train_input_10241.png',
#        'MyDrive/train/train_input_10242.png',
#        'MyDrive/train/train_input_10243.png',
#        'MyDrive/train/train_input_10244.png',
#        'MyDrive/train/train_input_10245.png',
#        'MyDrive/train/train_input_10246.png',
#        'MyDrive/train/train_input_10247.png',
#        'MyDrive/train/train_input_10248.png',
#        'MyDrive/train/train_input_10249.png',
#        'MyDrive/train/train_input_10250.png',
#        'MyDrive/train/train_input_10251.png',
#        'MyDrive/train/train_input_10252.png',
#        'MyDrive/train/train_input_10253.png',
#        'MyDrive/train/train_input_10254.png',
#        'MyDrive/train/train_input_10255.png',
#        'MyDrive/train/train_input_10256.png',
#        'MyDrive/train/train_input_10257.png',
#        'MyDrive/train/train_input_10258.png',
#        'MyDrive/train/train_input_10259.png',
#        'MyDrive/train/train_input_10260.png',
#        'MyDrive/train/train_input_10261.png',
#        'MyDrive/train/train_input_10262.png',
#        'MyDrive/train/train_input_10263.png',
#        'MyDrive/train/train_input_10264.png',
#        'MyDrive/train/train_input_10265.png',
#        'MyDrive/train/train_input_10266.png',
#        'MyDrive/train/train_input_10267.png',
#        'MyDrive/train/train_input_10268.png',
#        'MyDrive/train/train_input_10269.png',
#        'MyDrive/train/train_input_10270.png',
#        'MyDrive/train/train_input_10271.png',
#        'MyDrive/train/train_input_10272.png',
#        'MyDrive/train/train_input_10273.png',
#        'MyDrive/train/train_input_10274.png',
#        'MyDrive/train/train_input_10275.png',
#        'MyDrive/train/train_input_10276.png',
#        'MyDrive/train/train_input_10277.png',
#        'MyDrive/train/train_input_10278.png',
#        'MyDrive/train/train_input_10279.png',
#        'MyDrive/train/train_input_10280.png',
#        'MyDrive/train/train_input_10281.png',
#        'MyDrive/train/train_input_10282.png',
#        'MyDrive/train/train_input_10283.png',
#        'MyDrive/train/train_input_10284.png',
#        'MyDrive/train/train_input_10285.png',
#        'MyDrive/train/train_input_10286.png',
#        'MyDrive/train/train_input_10287.png',
#        'MyDrive/train/train_input_10288.png',
#        'MyDrive/train/train_input_10289.png',
#        'MyDrive/train/train_input_10290.png',
#        'MyDrive/train/train_input_10291.png',
#        'MyDrive/train/train_input_10292.png',
#        'MyDrive/train/train_input_10293.png',
#        'MyDrive/train/train_input_10294.png',
#        'MyDrive/train/train_input_10295.png',
#        'MyDrive/train/train_input_10296.png',
#        'MyDrive/train/train_input_10297.png',
#        'MyDrive/train/train_input_10298.png',
#        'MyDrive/train/train_input_10299.png',
#        'MyDrive/train/train_input_10300.png',
#        'MyDrive/train/train_input_10301.png',
#        'MyDrive/train/train_input_10302.png',
#        'MyDrive/train/train_input_10303.png',
#        'MyDrive/train/train_input_10304.png',
#        'MyDrive/train/train_input_10305.png',
#        'MyDrive/train/train_input_10306.png',
#        'MyDrive/train/train_input_10307.png',
#        'MyDrive/train/train_input_10308.png',
#        'MyDrive/train/train_input_10309.png',
#        'MyDrive/train/train_input_10310.png',
#        'MyDrive/train/train_input_10311.png',
#        'MyDrive/train/train_input_10312.png',
#        'MyDrive/train/train_input_10313.png',
#        'MyDrive/train/train_input_10314.png',
#        'MyDrive/train/train_input_10315.png',
#        'MyDrive/train/train_input_10316.png',
#        'MyDrive/train/train_input_10317.png',
#        'MyDrive/train/train_input_10318.png',
#        'MyDrive/train/train_input_10319.png',
#        'MyDrive/train/train_input_10320.png',
#        'MyDrive/train/train_input_10321.png',
#        'MyDrive/train/train_input_10322.png',
#        'MyDrive/train/train_input_10323.png',
#        'MyDrive/train/train_input_10324.png',
#        'MyDrive/train/train_input_10325.png',
#        'MyDrive/train/train_input_10326.png',
#        'MyDrive/train/train_input_10327.png',
#        'MyDrive/train/train_input_10328.png',
#        'MyDrive/train/train_input_10329.png',
#        'MyDrive/train/train_input_10330.png',
#        'MyDrive/train/train_input_10331.png',
#        'MyDrive/train/train_input_10332.png',
#        'MyDrive/train/train_input_10333.png',
#        'MyDrive/train/train_input_10334.png',
#        'MyDrive/train/train_input_10335.png',
#        'MyDrive/train/train_input_10336.png',
#        'MyDrive/train/train_input_10337.png',
#        'MyDrive/train/train_input_10338.png',
#        'MyDrive/train/train_input_10339.png',
#        'MyDrive/train/train_input_10340.png',
#        'MyDrive/train/train_input_10341.png',
#        'MyDrive/train/train_input_10342.png',
#        'MyDrive/train/train_input_10343.png',
#        'MyDrive/train/train_input_10344.png',
#        'MyDrive/train/train_input_10345.png',
#        'MyDrive/train/train_input_10346.png',
#        'MyDrive/train/train_input_10347.png',
#        'MyDrive/train/train_input_10348.png',
#        'MyDrive/train/train_input_10349.png',
#        'MyDrive/train/train_input_10350.png',
#        'MyDrive/train/train_input_10351.png',
#        'MyDrive/train/train_input_10352.png',
#        'MyDrive/train/train_input_10353.png',
#        'MyDrive/train/train_input_10354.png',
#        'MyDrive/train/train_input_10355.png',
#        'MyDrive/train/train_input_10356.png',
#        'MyDrive/train/train_input_10357.png',
#        'MyDrive/train/train_input_10358.png',
#        'MyDrive/train/train_input_10359.png',
#        'MyDrive/train/train_input_10360.png',
#        'MyDrive/train/train_input_10361.png',
#        'MyDrive/train/train_input_10362.png',
#        'MyDrive/train/train_input_10363.png',
#        'MyDrive/train/train_input_10364.png',
#        'MyDrive/train/train_input_10365.png',
#        'MyDrive/train/train_input_10366.png',
#        'MyDrive/train/train_input_10367.png',
#        'MyDrive/train/train_input_10368.png',
#        'MyDrive/train/train_input_10369.png',
#        'MyDrive/train/train_input_10370.png',
#        'MyDrive/train/train_input_10371.png',
#        'MyDrive/train/train_input_10372.png',
#        'MyDrive/train/train_input_10373.png',
#        'MyDrive/train/train_input_10374.png',
#        'MyDrive/train/train_input_10375.png',
#        'MyDrive/train/train_input_10376.png',
#        'MyDrive/train/train_input_10377.png',
#        'MyDrive/train/train_input_10378.png',
#        'MyDrive/train/train_input_10379.png',
#        'MyDrive/train/train_input_10380.png',
#        'MyDrive/train/train_input_10381.png',
#        'MyDrive/train/train_input_10382.png',
#        'MyDrive/train/train_input_10383.png',
#        'MyDrive/train/train_input_10384.png',
#        'MyDrive/train/train_input_10385.png',
#        'MyDrive/train/train_input_10386.png',
#        'MyDrive/train/train_input_10387.png',
#        'MyDrive/train/train_input_10388.png',
#        'MyDrive/train/train_input_10389.png',
#        'MyDrive/train/train_input_10390.png',
#        'MyDrive/train/train_input_10391.png',
#        'MyDrive/train/train_input_10392.png',
#        'MyDrive/train/train_input_10393.png',
#        'MyDrive/train/train_input_10394.png',
#        'MyDrive/train/train_input_10395.png',
#        'MyDrive/train/train_input_10396.png',
#        'MyDrive/train/train_input_10397.png',
#        'MyDrive/train/train_input_10398.png',
#        'MyDrive/train/train_input_10399.png',
#        'MyDrive/train/train_input_10400.png',
#        'MyDrive/train/train_input_10401.png',
#        'MyDrive/train/train_input_10402.png',
#        'MyDrive/train/train_input_10403.png',
#        'MyDrive/train/train_input_10404.png',
#        'MyDrive/train/train_input_10405.png',
#        'MyDrive/train/train_input_10406.png',
#        'MyDrive/train/train_input_10407.png',
#        'MyDrive/train/train_input_10408.png',
#        'MyDrive/train/train_input_10409.png',
#        'MyDrive/train/train_input_10410.png',
#        'MyDrive/train/train_input_10411.png',
#        'MyDrive/train/train_input_10412.png',
#        'MyDrive/train/train_input_10413.png',
#        'MyDrive/train/train_input_10414.png',
#        'MyDrive/train/train_input_10415.png',
#        'MyDrive/train/train_input_10416.png',
#        'MyDrive/train/train_input_10417.png',
#        'MyDrive/train/train_input_10418.png',
#        'MyDrive/train/train_input_10419.png',
#        'MyDrive/train/train_input_10420.png',
#        'MyDrive/train/train_input_10421.png',
#        'MyDrive/train/train_input_10422.png',
#        'MyDrive/train/train_input_10423.png',
#        'MyDrive/train/train_input_10424.png',
#        'MyDrive/train/train_input_10425.png',
#        'MyDrive/train/train_input_10426.png',
#        'MyDrive/train/train_input_10427.png',
#        'MyDrive/train/train_input_10428.png',
#        'MyDrive/train/train_input_10429.png',
#        'MyDrive/train/train_input_10430.png',
#        'MyDrive/train/train_input_10431.png',
#        'MyDrive/train/train_input_10432.png',
#        'MyDrive/train/train_input_10433.png',
#        'MyDrive/train/train_input_10434.png',
#        'MyDrive/train/train_input_10435.png',
#        'MyDrive/train/train_input_10436.png',
#        'MyDrive/train/train_input_10437.png',
#        'MyDrive/train/train_input_10438.png',
#        'MyDrive/train/train_input_10439.png',
#        'MyDrive/train/train_input_10440.png',
#        'MyDrive/train/train_input_10441.png',
#        'MyDrive/train/train_input_10442.png',
#        'MyDrive/train/train_input_10443.png',
#        'MyDrive/train/train_input_10444.png',
#        'MyDrive/train/train_input_10445.png',
#        'MyDrive/train/train_input_10446.png',
#        'MyDrive/train/train_input_10447.png',
#        'MyDrive/train/train_input_10448.png',
#        'MyDrive/train/train_input_10449.png',
#        'MyDrive/train/train_input_10450.png',
#        'MyDrive/train/train_input_10451.png',
#        'MyDrive/train/train_input_10452.png',
#        'MyDrive/train/train_input_10453.png',
#        'MyDrive/train/train_input_10454.png',
#        'MyDrive/train/train_input_10455.png',
#        'MyDrive/train/train_input_10456.png',
#        'MyDrive/train/train_input_10457.png',
#        'MyDrive/train/train_input_10458.png',
#        'MyDrive/train/train_input_10459.png',
#        'MyDrive/train/train_input_10460.png',
#        'MyDrive/train/train_input_10461.png',
#        'MyDrive/train/train_input_10462.png',
#        'MyDrive/train/train_input_10463.png',
#        'MyDrive/train/train_input_10464.png',
#        'MyDrive/train/train_input_10465.png',
#        'MyDrive/train/train_input_10466.png',
#        'MyDrive/train/train_input_10467.png',
#        'MyDrive/train/train_input_10468.png',
#        'MyDrive/train/train_input_10469.png',
#        'MyDrive/train/train_input_10470.png',
#        'MyDrive/train/train_input_10471.png',
#        'MyDrive/train/train_input_10472.png',
#        'MyDrive/train/train_input_10473.png',
#        'MyDrive/train/train_input_10474.png',
#        'MyDrive/train/train_input_10475.png',
#        'MyDrive/train/train_input_10476.png',
#        'MyDrive/train/train_input_10477.png',
#        'MyDrive/train/train_input_10478.png',
#        'MyDrive/train/train_input_10479.png',
#        'MyDrive/train/train_input_10480.png',
#        'MyDrive/train/train_input_10481.png',
#        'MyDrive/train/train_input_10482.png',
#        'MyDrive/train/train_input_10483.png',
#        'MyDrive/train/train_input_10484.png',
#        'MyDrive/train/train_input_10485.png',
#        'MyDrive/train/train_input_10486.png',
#        'MyDrive/train/train_input_10487.png',
#        'MyDrive/train/train_input_10488.png',
#        'MyDrive/train/train_input_10489.png',
#        'MyDrive/train/train_input_10490.png',
#        'MyDrive/train/train_input_10491.png',
#        'MyDrive/train/train_input_10492.png',
#        'MyDrive/train/train_input_10493.png',
#        'MyDrive/train/train_input_10494.png',
#        'MyDrive/train/train_input_10495.png',
#        'MyDrive/train/train_input_10496.png',
#        'MyDrive/train/train_input_10497.png',
#        'MyDrive/train/train_input_10498.png',
#        'MyDrive/train/train_input_10499.png',
#        'MyDrive/train/train_input_10500.png',
#        'MyDrive/train/train_input_10501.png',
#        'MyDrive/train/train_input_10502.png',
#        'MyDrive/train/train_input_10503.png',
#        'MyDrive/train/train_input_10504.png',
#        'MyDrive/train/train_input_10505.png',
#        'MyDrive/train/train_input_10506.png',
#        'MyDrive/train/train_input_10507.png',
#        'MyDrive/train/train_input_10508.png',
#        'MyDrive/train/train_input_10509.png',
#        'MyDrive/train/train_input_10510.png',
#        'MyDrive/train/train_input_10511.png',
#        'MyDrive/train/train_input_10512.png',
#        'MyDrive/train/train_input_10513.png',
#        'MyDrive/train/train_input_10514.png',
#        'MyDrive/train/train_input_10515.png',
#        'MyDrive/train/train_input_10516.png',
#        'MyDrive/train/train_input_10517.png',
#        'MyDrive/train/train_input_10518.png',
#        'MyDrive/train/train_input_10519.png',
#        'MyDrive/train/train_input_10520.png',
#        'MyDrive/train/train_input_10521.png',
#        'MyDrive/train/train_input_10522.png',
#        'MyDrive/train/train_input_10523.png',
#        'MyDrive/train/train_input_10524.png',
#        'MyDrive/train/train_input_10525.png',
#        'MyDrive/train/train_input_10526.png',
#        'MyDrive/train/train_input_10527.png',
#        'MyDrive/train/train_input_10528.png',
#        'MyDrive/train/train_input_10529.png',
#        'MyDrive/train/train_input_10530.png',
#        'MyDrive/train/train_input_10531.png',
#        'MyDrive/train/train_input_10532.png',
#        'MyDrive/train/train_input_10533.png',
#        'MyDrive/train/train_input_10534.png',
#        'MyDrive/train/train_input_10535.png',
#        'MyDrive/train/train_input_10536.png',
#        'MyDrive/train/train_input_10537.png',
#        'MyDrive/train/train_input_10538.png',
#        'MyDrive/train/train_input_10539.png',
#        'MyDrive/train/train_input_10540.png',
#        'MyDrive/train/train_input_10541.png',
#        'MyDrive/train/train_input_10542.png',
#        'MyDrive/train/train_input_10543.png',
#        'MyDrive/train/train_input_10544.png',
#        'MyDrive/train/train_input_10545.png',
#        'MyDrive/train/train_input_10546.png',
#        'MyDrive/train/train_input_10547.png',
#        'MyDrive/train/train_input_10548.png',
#        'MyDrive/train/train_input_10549.png',
#        'MyDrive/train/train_input_10550.png',
#        'MyDrive/train/train_input_10551.png',
#        'MyDrive/train/train_input_10552.png',
#        'MyDrive/train/train_input_10553.png',
#        'MyDrive/train/train_input_10554.png',
#        'MyDrive/train/train_input_10555.png',
#        'MyDrive/train/train_input_10556.png',
#        'MyDrive/train/train_input_10557.png',
#        'MyDrive/train/train_input_10558.png',
#        'MyDrive/train/train_input_10559.png',
#        'MyDrive/train/train_input_10560.png',
#        'MyDrive/train/train_input_10561.png',
#        'MyDrive/train/train_input_10562.png',
#        'MyDrive/train/train_input_10563.png',
#        'MyDrive/train/train_input_10564.png',
#        'MyDrive/train/train_input_10565.png',
#        'MyDrive/train/train_input_10566.png',
#        'MyDrive/train/train_input_10567.png',
#        'MyDrive/train/train_input_10568.png',
#        'MyDrive/train/train_input_10569.png',
#        'MyDrive/train/train_input_10570.png',
#        'MyDrive/train/train_input_10571.png',
#        'MyDrive/train/train_input_10572.png',
#        'MyDrive/train/train_input_10573.png',
#        'MyDrive/train/train_input_10574.png',
#        'MyDrive/train/train_input_10575.png',
#        'MyDrive/train/train_input_10576.png',
#        'MyDrive/train/train_input_10577.png',
#        'MyDrive/train/train_input_10578.png',
#        'MyDrive/train/train_input_10579.png',
#        'MyDrive/train/train_input_10580.png',
#        'MyDrive/train/train_input_10581.png',
#        'MyDrive/train/train_input_10582.png',
#        'MyDrive/train/train_input_10583.png',
#        'MyDrive/train/train_input_10584.png',
#        'MyDrive/train/train_input_10585.png',
#        'MyDrive/train/train_input_10586.png',
#        'MyDrive/train/train_input_10587.png',
#        'MyDrive/train/train_input_10588.png',
#        'MyDrive/train/train_input_10589.png',
#        'MyDrive/train/train_input_10590.png',
#        'MyDrive/train/train_input_10591.png',
#        'MyDrive/train/train_input_10592.png',
#        'MyDrive/train/train_input_10593.png',
#        'MyDrive/train/train_input_10594.png',
#        'MyDrive/train/train_input_10595.png',
#        'MyDrive/train/train_input_10596.png',
#        'MyDrive/train/train_input_10597.png',
#        'MyDrive/train/train_input_10598.png',
#        'MyDrive/train/train_input_10599.png',
#        'MyDrive/train/train_input_10600.png',
#        'MyDrive/train/train_input_10601.png',
#        'MyDrive/train/train_input_10602.png',
#        'MyDrive/train/train_input_10603.png',
#        'MyDrive/train/train_input_10604.png',
#        'MyDrive/train/train_input_10605.png',
#        'MyDrive/train/train_input_10606.png',
#        'MyDrive/train/train_input_10607.png',
#        'MyDrive/train/train_input_10608.png',
#        'MyDrive/train/train_input_10609.png',
#        'MyDrive/train/train_input_10610.png',
#        'MyDrive/train/train_input_10611.png',
#        'MyDrive/train/train_input_10612.png',
#        'MyDrive/train/train_input_10613.png',
#        'MyDrive/train/train_input_10614.png',
#        'MyDrive/train/train_input_10615.png',
#        'MyDrive/train/train_input_10616.png',
#        'MyDrive/train/train_input_10617.png',
#        'MyDrive/train/train_input_10618.png',
#        'MyDrive/train/train_input_10619.png',
#        'MyDrive/train/train_input_10620.png',
#        'MyDrive/train/train_input_10621.png'], dtype=object)

# %%
vaild_input_files
# Out:
# array(['MyDrive/train/train_input_10000.png',
#        'MyDrive/train/train_input_10001.png',
#        'MyDrive/train/train_input_10002.png',
#        'MyDrive/train/train_input_10003.png',
#        'MyDrive/train/train_input_10004.png',
#        'MyDrive/train/train_input_10005.png',
#        'MyDrive/train/train_input_10006.png',
#        'MyDrive/train/train_input_10007.png',
#        'MyDrive/train/train_input_10008.png',
#        'MyDrive/train/train_input_10009.png',
#        'MyDrive/train/train_input_10010.png',
#        'MyDrive/train/train_input_10011.png',
#        'MyDrive/train/train_input_10012.png',
#        'MyDrive/train/train_input_10013.png',
#        'MyDrive/train/train_input_10014.png',
#        'MyDrive/train/train_input_10015.png',
#        'MyDrive/train/train_input_10016.png',
#        'MyDrive/train/train_input_10017.png',
#        'MyDrive/train/train_input_10018.png',
#        'MyDrive/train/train_input_10019.png',
#        'MyDrive/train/train_input_10020.png',
#        'MyDrive/train/train_input_10021.png',
#        'MyDrive/train/train_input_10022.png',
#        'MyDrive/train/train_input_10023.png',
#        'MyDrive/train/train_input_10024.png',
#        'MyDrive/train/train_input_10025.png',
#        'MyDrive/train/train_input_10026.png',
#        'MyDrive/train/train_input_10027.png',
#        'MyDrive/train/train_input_10028.png',
#        'MyDrive/train/train_input_10029.png',
#        'MyDrive/train/train_input_10030.png',
#        'MyDrive/train/train_input_10031.png',
#        'MyDrive/train/train_input_10032.png',
#        'MyDrive/train/train_input_10033.png',
#        'MyDrive/train/train_input_10034.png',
#        'MyDrive/train/train_input_10035.png',
#        'MyDrive/train/train_input_10036.png',
#        'MyDrive/train/train_input_10037.png',
#        'MyDrive/train/train_input_10038.png',
#        'MyDrive/train/train_input_10039.png',
#        'MyDrive/train/train_input_10040.png',
#        'MyDrive/train/train_input_10041.png',
#        'MyDrive/train/train_input_10042.png',
#        'MyDrive/train/train_input_10043.png',
#        'MyDrive/train/train_input_10044.png',
#        'MyDrive/train/train_input_10045.png',
#        'MyDrive/train/train_input_10046.png',
#        'MyDrive/train/train_input_10047.png',
#        'MyDrive/train/train_input_10048.png',
#        'MyDrive/train/train_input_10049.png',
#        'MyDrive/train/train_input_10050.png',
#        'MyDrive/train/train_input_10051.png',
#        'MyDrive/train/train_input_10052.png',
#        'MyDrive/train/train_input_10053.png',
#        'MyDrive/train/train_input_10054.png',
#        'MyDrive/train/train_input_10055.png',
#        'MyDrive/train/train_input_10056.png',
#        'MyDrive/train/train_input_10057.png',
#        'MyDrive/train/train_input_10058.png',
#        'MyDrive/train/train_input_10059.png'], dtype=object)

# %% [markdown]
# # 빛번짐 데이터 열어서 확인

# %%
for i in range(4):
    origin_img = Image.open(f'MyDrive/train/train_input_{i+10060}.png')
    trans_img = Image.open(f'MyDrive/label/train_label_{i+10060}.png')
    fix , ax = plt.subplots(ncols = 2,figsize = (8,8))
    ax[0].set_title('input')
    ax[0].imshow(origin_img)
    ax[1].set_title('label')
    ax[1].imshow(trans_img)
    plt.show()

# %% [markdown]
# # 빛번짐 최소화 데이터 처리
#
# 제공된 데이터의 크기(3264*2448 , 1632*1224)를 512*384의 크기로 축소시키는 과정을 거침
#
#  데이터의 크기와 사용하는 인공지능 신경망을 gpu에 할당할 때 현재 colab에서 제공되는 최대 GPU는 15GB로 데이터 크기 그대로 사용했을 때 15GB로는 메모리가 부족한 현상이 발생해서 15GB에 최대한 맞는 크기로 이미지를 축소한 결과 512*384인걸 확인해서 이미지를 축소함
#
#  만약 GPU MEMORY가 더 큰 GPU를 사용한다면 최대한 이미지의 크기를 보존하도록 하는 게 좋음
# -이미지를 축소한다는 것은 이미지의 정보에 대해서 손실이 일어난다는 것을 의미하기 때문에

# %%
class CustomDataset(Dataset):
    def __init__(self, data, label,w,h ,is_train=True):
        self.data  = data
        self.label = label
        self.w = w
        self.h = h
        self.is_train = is_train
        
    def __len__(self):
        return len(self.data)
    
    def transform(self, image, label):
        
        resizer = transforms.Resize(size=(self.h, self.w))
        image = resizer(image)
        label = resizer(label)

        image = TF.to_tensor(image)
        label = TF.to_tensor(label)
        return image, label
    
    def __getitem__(self, idx):
        origin_img = Image.open(self.data[idx])
        label_img  = Image.open(self.label[idx])
        
        origin_img, label_img = self.transform(origin_img, label_img)
        return origin_img, label_img
    
#def __init__는 생성자
#def __len__은 데이셋의 길이를 변환
#def __transform 에서 resize = 이미지 크기 재지정 , to_tensor = 이미지를 tensor형으로 변경
#def __getitem__은 이미지를 호출하고 transform함수를 적용 시킨 후 이미지를 호출

# %%
class testDataset(Dataset):
    def __init__(self, data,is_train=True):
        self.data  = data
        self.is_train = is_train
        
    def __len__(self):
        return len(self.data)
    
    def transform(self, image):
        
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.CenterCrop(36,36)
            transforms.Resize(size=(384, 512))
        ])
        image = transform(image)
        
        return image
    
    def __getitem__(self, idx):
        origin_img = Image.open(self.data[idx]).convert("RGB")
        
        origin_img = self.transform(origin_img)
        return origin_img

# %%
train_dataset = CustomDataset(train_input_files, train_label_files,512,384)
vaild_dataset = CustomDataset(vaild_input_files, vaild_label_files,512,384)
test_dataset = testDataset(test_all_input_files)

# %%
for i in range(4):
    origin_img = Image.open(f'MyDrive/train/train_input_{i+10060}.png')
    trans_img = train_dataset[i][0].numpy().transpose(1,2,0)
    fix , ax = plt.subplots(ncols = 2,figsize = (8,8))
    ax[0].set_title('before reduce')
    ax[0].imshow(origin_img)
    ax[1].set_title('after reduce')
    ax[1].imshow(trans_img)
    plt.show()

# %%
train_loader = DataLoader(train_dataset , batch_size = 4, shuffle = True)
vaild_loader = DataLoader(vaild_dataset , batch_size = 1, shuffle = False)
test_loader = DataLoader(test_dataset , batch_size = 4 , shuffle = True )

# %% [markdown]
# # 빛번짐 최소화 인공지능 모델 선정
#
#  개발 시 사용할 인공지능 신경망으로는 CNN을 선정
# 다른 신경망들과 다르게 이미지 데이터를 처리 할 때 이미지의 단순한 특징 뿐만 아니라 패턴까지 알아 낼 수 있는 장점이 있기 때문임
#
#  선정한 모델로는 Resnet , Mobilenet , Efficientnet임
# -3가지 모델은 Resnet > Mobilenet > Efficinetnet으로
# 인공지능의 모델의 크기에 따른 성능을 비교하기 위해 위의 모델들을 선정하였음
#
#  단 개발시에는 다른 모델을 사용해도 상관 없으나 CNN을 기초로 한 인공지능 모델을 선정하는 것을 추천
# -단순히 특징만 추출해내는 DNN같은 신경망으로 해도 문제는 없으나 효과를 기대하기는 CNN에 비해서 기대 효과를 얻기 어렵기 때문임.

# %%
model = smp.UnetPlusPlus(encoder_name='efficientnet-b0',
                encoder_weights='imagenet',
                in_channels=3, classes=3, activation='sigmoid')

'''
model = smp.UnetPlusPlus(encoder_name='efficientnet-b4',
                encoder_weights='imagenet',
                in_channels=3, classes=3, activation='sigmoid')
                

model = smp.UnetPlusPlus(encoder_name='mobilenet_v2',
                encoder_weights='imagenet',
                in_channels=3, classes=3, activation='sigmoid')
'''
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b0-355c32eb.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b0-355c32eb.pth
#   0%|          | 0.00/20.4M [00:00<?, ?B/s]
# "\nmodel = smp.UnetPlusPlus(encoder_name='efficientnet-b4',\n                encoder_weights='imagenet',\n                in_channels=3, classes=3, activation='sigmoid')\n                \n\nmodel = smp.UnetPlusPlus(encoder_name='mobilenet_v2',\n                encoder_weights='imagenet',\n                in_channels=3, classes=3, activation='sigmoid')\n"

# %%
model.to(device)
model
model.load_state_dict(torch.load('/content/drive/MyDrive/weight/efficientnet.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # 빛번짐 최소화 인공지능 모델 학습
#
# 빛번짐 최소화 인공지능 모델 학습
#
#  선정한 모델 Resnet , Mobilenet , Efficientnet을 조원끼리 하나씩 맡아서 각자의 기기로 학습을 진행
#
#  하나의 모델에 대해서 학습당 시간이 약 5분정도가 소요되고 최소한 성능을 내기 위해서는 100회 이상의 학습량이 필요했음. (ex)100회 학습 시 500분 소요)
#
#  개발 환경 구축 , 데이터 수집 , 데이터 처리까지는 각자모두 같은 과정을 수행하고 각자 모델을 하나씩 맡아서 ex)고창환은 resnet, 김선영은 mobilenet
# 300번의 횟수로 학습을 진행하였음
#
#   -한 학기의 시간동안 빠르게 인공지능을 완성해야 하였기 때문에 위와 같은 방식을 선정하였음

# %%
criterion = torch.nn.MSELoss().to(device) #예상 답과 실제 답의 차이를 줄이기 위한 함수
optimizer = torch.optim.Adam(model.parameters(), lr=0.001) #가중치를 갱신해주는 함수
scheduler = torch.optim.lr_scheduler.StepLR(optimizer,step_size = 10, gamma=0.8)#학습에 사용 되는 가중치를 조절해주는 함수

# %%
'''
train_loss = []
vaild_loss=[]
model.load_state_dict(torch,load('data/resnet.pt'))
for epoch in range(300):
    total_loss = 0
    model.train()
    
    for image , label in tqdm(train_loader,total=len(train_loader),leave = False):
        image = image.to(device)
        label = label.to(device)
        output = model(image.float())
        loss = torch.sqrt(criterion(output,label))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    train_loss.append(total_loss/len(train_loader))
    torch.save(model.state_dict(), 'data/resnet.pt')
    print("epoch :" , epoch+1 , "loss :" , total_loss/len(train_loader))
    
    scheduler.step()
    
    idx = 1
    
    model.eval()
    with torch.no_grad():
        for image , label in tqdm(vaild_loader,total=len(vaild_loader),leave = False):
            image = image.to(device)
            label = label.to(device)
            output = model(image.float())
            loss = torch.sqrt(criterion(output,label))
            
            total_loss += loss.item()
            

            target_path = 'data/result/' + str(epoch+1)+'/'
            if not os.path.exists(target_path):
                os.makedirs(target_path, exist_ok=True)

            grid = torchvision.utils.make_grid(tensor=torch.vstack([image,label,output]), nrow=image.shape[0])    # Saving results
            torchvision.utils.save_image(grid, target_path+str(idx)+'.png')
            idx +=1
        vaild_loss.append(total_loss/len(vaild_loader))
        print("val_epoch :" , epoch+1 , "val_loss :" , total_loss/len(vaild_loader))
    

#요약으로 dataset에서 문제(image)와 답지(label)을 호출 하고 model에 문제를 넣음(output = modle(image))
#output은 예상 답을 의미 하고 loss변수는 예상 답과 실제 답에 대한 차이를 줄여 나감
#zero_grad는 가중치를 초기화해주는 함수
#loss backward는 역전파 알고리즘에 대한 것으로 신경망 방향을 순방향으로 한번 역방향으로 한번 확인 후 비교를 하는 것
'''
# Out:
# '\ntrain_loss = []\nvaild_loss=[]\nmodel.load_state_dict(torch,load(\'data/resnet.pt\'))\nfor epoch in range(300):\n    total_loss = 0\n    model.train()\n    \n    for image , label in tqdm(train_loader,total=len(train_loader),leave = False):\n        image = image.to(device)\n        label = label.to(device)\n        output = model(image.float())\n        loss = torch.sqrt(criterion(output,label))\n        optimizer.zero_grad()\n        loss.backward()\n        optimizer.step()\n        total_loss += loss.item()\n    train_loss.append(total_loss/len(train_loader))\n    torch.save(model.state_dict(), \'data/resnet.pt\')\n    print("epoch :" , epoch+1 , "loss :" , total_loss/len(train_loader))\n    \n    scheduler.step()\n    \n    idx = 1\n    \n    model.eval()\n    with torch.no_grad():\n        for image , label in tqdm(vaild_loader,total=len(vaild_loader),leave = False):\n            image = image.to(device)\n            label = label.to(device)\n            output = model(image.float())\n            loss = torch.sqrt(criterion(output,label))\n            \n            total_loss += loss.item()\n            \n\n            target_path = \'data/result/\' + str(epoch+1)+\'/\'\n            if not os.path.exists(target_path):\n                os.makedirs(target_path, exist_ok=True)\n\n            grid = torchvision.utils.make_grid(tensor=torch.vstack([image,label,output]), nrow=image.shape[0])    # Saving results\n            torchvision.utils.save_image(grid, target_path+str(idx)+\'.png\')\n            idx +=1\n        vaild_loss.append(total_loss/len(vaild_loader))\n        print("val_epoch :" , epoch+1 , "val_loss :" , total_loss/len(vaild_loader))\n    \n\n#요약으로 dataset에서 문제(image)와 답지(label)을 호출 하고 model에 문제를 넣음(output = modle(image))\n#output은 예상 답을 의미 하고 loss변수는 예상 답과 실제 답에 대한 차이를 줄여 나감\n#zero_grad는 가중치를 초기화해주는 함수\n#loss backward는 역전파 알고리즘에 대한 것으로 신경망 방향을 순방향으로 한번 역방향으로 한번 확인 후 비교를 하는 것\n'

# %% [markdown]
# # 빛번짐 모델 검증
#
# 빛번짐 최소화 인공지능 모델 검증
#
#  검증용(학습 때 사용하지 않음)으로 사용하기로 했던 60개의 빛이 번져있는 사진과 번져있지 않은 사진을 준비해서 번져있는 사진을 학습이 끝난 인공지능 모델에 넣고 그에 대한 결과를 번져있지 않은 사진과 비교해서 얼마나 빛이 잘 줄어들었는지 확인
#
#  수치적으로 이를 검증할 수 없기 때문에 시각적으로 가장 빛을 잘 줄였다고 생각한 모델을 가장 빛을 최소화시킨 모델로 선정하기로 하고 이 모델을 최종적인 빛번짐 최소화 모델로 선정
#
#  resnet mobilenet efficinetnet중 efficientnet이 가장 시각적으로 빛을 잘 줄였다고 생각해 efiicinetnet을 선정하였음

# %%
'''
model.eval()
model.load_state_dict(torch.load( 'MyDrive/weight/efficientnet.pt'))
for image,label in vaild_loader:
    recon = model(image.to(device))
    _, ax = plt.subplots(1, 3, figsize=(15,15))
    ax[0].set_title('input')
    ax[0].imshow(np.moveaxis(image.reshape(3,384,512).cpu().numpy(),0,2))
    ax[1].set_title('label')
    ax[1].imshow(np.moveaxis(label.reshape(3,384,512).cpu().numpy(),0,2))
    ax[2].set_title('predict')
    ax[2].imshow(np.moveaxis(recon.reshape(3,384,512).cpu().detach().numpy(),0,2))
    '''
# Out:
# "\nmodel.eval()\nmodel.load_state_dict(torch.load( 'MyDrive/weight/efficientnet.pt'))\nfor image,label in vaild_loader:\n    recon = model(image.to(device))\n    _, ax = plt.subplots(1, 3, figsize=(15,15))\n    ax[0].set_title('input')\n    ax[0].imshow(np.moveaxis(image.reshape(3,384,512).cpu().numpy(),0,2))\n    ax[1].set_title('label')\n    ax[1].imshow(np.moveaxis(label.reshape(3,384,512).cpu().numpy(),0,2))\n    ax[2].set_title('predict')\n    ax[2].imshow(np.moveaxis(recon.reshape(3,384,512).cpu().detach().numpy(),0,2))\n    "

# %% [markdown]
# # 밤낮 전환 인공지능 데이터 수집
#
# kaggle : https://www.kaggle.com/datasets/solesensei/solesensei_bdd100k
#
# Kaggle에서 낮에 찍힌 블랙박스 영상을 이미지로 분할한 사진과 밤에 블랙박스 영상을 이미지로 분할한 데이터셋을 다운로드
#
#  모두 비정형 데이터이며 이미지 크기는 모두 1080*720으로 이루어져 있고 jpg형식의 비정형 데이터임.
#
#  개발 시 다운 받은 데이터셋(약 밤사진 20000장 낮 사진 20000장)에서 밤사진 4000장 과 낮사진4000 장을 가지고 와서 학습 데이터로 사용함
#
#  데이터를 모두 사용하면 좋으나 이 또한 한달안에 인공지능을 개발해야 하기 때문에 데이터 수를 줄여서 빠르게 결과를 보기 위해서 사용

# %%
cd '/content/drive/'
# Out:
# /content/drive

# %% [markdown]
# # 밤낮 데이터 파일 크기 및 확인

# %%
origin_img = Image.open(f'MyDrive/night/795378f0-db2d80b2.jpg')
trans_img = Image.open(f'MyDrive/day/58610009-f3b500dd.jpg')
fix , ax = plt.subplots(ncols = 2,figsize = (8,8))
ax[0].set_title('input(night)')
ax[0].imshow(origin_img)
ax[1].set_title('label(day)')
ax[1].imshow(trans_img)
plt.show()

# %%
cd 'MyDrive/night'
# Out:
# /content/drive/MyDrive/night

# %%
ls
# Out:
# 01638325-504ab42d.jpg  979242ca-1e27d0a0.jpg  a8ff323e-e688921b.jpg
# 01638325-901cd4f5.jpg  982339f8-a79f93b8.jpg  a8ff598e-1179b5cc.jpg
# 01638325-c0f998fd.jpg  98240374-17fb2fb7.jpg  a8ff598e-cf186f1e.jpg
# 01638325-eb95ed3a.jpg  98240374-d25880e3.jpg  a901dfcb-78a02ed5.jpg
# 01759047-d88724fe.jpg  98240374-dc94a5fd.jpg  a907b828-f83d3ee0.jpg
# 02097021-183ed3b9.jpg  9833851c-40114f7e.jpg  a9083001-cbe8b531.jpg
# 02858212-e0d90c01.jpg  9833851c-66bcf280.jpg  a908e2f2-6249e255.jpg
# 02858212-eea55b78.jpg  9833851c-7c6eb449.jpg  a908e2f2-b28a443a.jpg
# 03009421-80952641.jpg  9833851c-93260238.jpg  a908e2f2-f692ab4c.jpg
# a3bac621-f7fa4db1.jpg  a9c77142-750fef71.jpg  b0d7053d-5a1c1396.jpg
# a3bc6078-722dfbfe.jpg  a9c8091c-55170794.jpg  b0d7eaa8-5db68c1f.jpg
# a3bc6078-99e96be8.jpg  a9c8091c-71b2088d.jpg  b0d85b9e-5103228c.jpg
# a3bc6078-cdd732a0.jpg  a9c8091c-7bf57064.jpg  b0d85b9e-6e5bbd47.jpg
# a3bc6078-f3b5ce2a.jpg  a9c8091c-b76e7006.jpg  b0d886df-e42b3458.jpg
# a3bed343-206167b4.jpg  a9c8091c-c67ba906.jpg  b0d97c4a-31222b85.jpg
# a3bed343-235e94f1.jpg  a9c8091c-ed6ed8f8.jpg  b0d97c4a-d61358d1.jpg
# a3bed343-3e7e3ec7.jpg  a9cab8d1-5201249e.jpg  b0da8564-8576eeb1.jpg
# a3bed343-b154db3d.jpg  a9cab8d1-b5aa86eb.jpg  b0daef2e-5fcd4ac1.jpg
# a3bed343-c6ae947d.jpg  a9cbeeb4-c3c5b6c2.jpg  b0ddecde-07d3f587.jpg
# a3bed343-dfa91c4c.jpg  a9d0a783-c3077d6e.jpg  b0de14a0-48d62400.jpg
# a3bed343-f6083eb8.jpg  a9d1bd2b-8f1f79f7.jpg  b0de1dff-70e80c1f.jpg
# a3bf3224-2b481a3a.jpg  a9d2431c-0ba00da2.jpg  b0de73ec-e9f2b7a3.jpg
# a3bf3224-32e2c2b0.jpg  a9d88883-a7c80885.jpg  b0df1a1e-7eb77823.jpg
# a3bf9c3c-1ac81835.jpg  a9da49b1-199a9b2a.jpg
# a3bf9c3c-a15c1bc7.jpg  a9da49b1-9979b4ab.jpg

# %%
cd '/content/drive/MyDrive'
# Out:
# /content/drive/MyDrive

# %% [markdown]
# # 밤낮 전환 인공지능 데이터 처리
#
# 빛번짐과 똑같이 처리함 이유 또한 동일
#
# -1280 * 720 이미지를 512* 384로 축소

# %%
class Dataset(object):
    def __init__(self, label_dir, input_dir, image_size, scale):
        self.label_dir = [os.path.join(label_dir, x) for x in os.listdir(label_dir) if self.check_image_file(x)]
        self.input_dir = [os.path.join(input_dir, x) for x in os.listdir(input_dir) if self.check_image_file(x)]
        self.image_size = image_size
        self.to_Tensor = transforms.ToTensor()
        self.resize = transforms.Resize((128 , 128 ), interpolation=Image.BICUBIC)
        self.rotates = [0, 90, 180, 270]
    
    def check_image_file(self, filename: str):
        return any(filename.endswith(extension) for extension in [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".JPG", ".JPEG", ".PNG", ".BMP"])
    
    def data_augmentation(self, hr, lr):

        width, height = hr.size
        
        hr = hr.resize((512, 384), resample=Image.BICUBIC)
        lr = lr.resize((512, 384), resample=Image.BICUBIC)
    
        return hr, lr

    def __getitem__(self, idx):
    
    
        hr = Image.open(self.label_dir[idx]).convert("RGB")
        lr = Image.open(self.input_dir[idx]).convert("RGB") 

        hr, lr = self.data_augmentation(hr, lr) 
        
        return self.to_Tensor(hr), self.to_Tensor(lr) 

    def __len__(self):
        return len(self.label_dir)

# %%
class TestDataset(object):
    def __init__(self, input_dir, image_size, scale):
        self.input_dir = sorted([os.path.join(input_dir, x) for x in os.listdir(input_dir) if self.check_image_file(x)])
        self.image_size = image_size
        self.to_Tensor = transforms.ToTensor()
        self.resize = transforms.Resize((image_size , image_size ), interpolation=Image.BICUBIC)
        self.rotates = [0, 90, 180, 270]
     
    
    def check_image_file(self, filename: str):
        return any(filename.endswith(extension) for extension in [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".JPG", ".JPEG", ".PNG", ".BMP"])
    

    def data_augmentation(self, hr):

        width, height = hr.size

        hr = hr.resize((512, 384), resample=Image.BICUBIC) # 테스트용은 밤 하나이기 때문.

        return hr

    def __getitem__(self, idx):

        hr = Image.open(self.input_dir[idx]).convert("RGB")

        hr = self.data_augmentation(hr) 
        return self.to_Tensor(hr)

    def __len__(self):
        return len(self.input_dir)

# %%
train_dir = '/content/drive/MyDrive/night/' # 밤
label_dir = '/content/drive/MyDrive/day/' # 낮
test_dir = sorted(glob('/content/drive/MyDrive/day_night/*.jpg')) #테스트 값.

# %%
print(test_dir)
# Out:
# ['/content/drive/MyDrive/day_night/Image00001.jpg', '/content/drive/MyDrive/day_night/Image00002.jpg', '/content/drive/MyDrive/day_night/Image00003.jpg', '/content/drive/MyDrive/day_night/Image00004.jpg', '/content/drive/MyDrive/day_night/Image00005.jpg', '/content/drive/MyDrive/day_night/Image00006.jpg', '/content/drive/MyDrive/day_night/Image00007.jpg', '/content/drive/MyDrive/day_night/Image00008.jpg', '/content/drive/MyDrive/day_night/Image00009.jpg', '/content/drive/MyDrive/day_night/Image00010.jpg', '/content/drive/MyDrive/day_night/Image00011.jpg', '/content/drive/MyDrive/day_night/Image00012.jpg', '/content/drive/MyDrive/day_night/Image00013.jpg', '/content/drive/MyDrive/day_night/Image00014.jpg', '/content/drive/MyDrive/day_night/Image00015.jpg', '/content/drive/MyDrive/day_night/Image00016.jpg', '/content/drive/MyDrive/day_night/Image00017.jpg', '/content/drive/MyDrive/day_night/Image00018.jpg', '/content/drive/MyDrive/day_night/Image00019.jpg', '/content/drive/MyDrive/day_night/Image00020.jpg', '/content/drive/MyDrive/day_night/Image00021.jpg', '/content/drive/MyDrive/day_night/Image00022.jpg', '/content/drive/MyDrive/day_night/Image00023.jpg', '/content/drive/MyDrive/day_night/Image00024.jpg', '/content/drive/MyDrive/day_night/Image00025.jpg', '/content/drive/MyDrive/day_night/Image00026.jpg', '/content/drive/MyDrive/day_night/Image00027.jpg', '/content/drive/MyDrive/day_night/Image00028.jpg', '/content/drive/MyDrive/day_night/Image00029.jpg', '/content/drive/MyDrive/day_night/Image00030.jpg', '/content/drive/MyDrive/day_night/Image00031.jpg', '/content/drive/MyDrive/day_night/Image00032.jpg', '/content/drive/MyDrive/day_night/Image00033.jpg', '/content/drive/MyDrive/day_night/Image00034.jpg', '/content/drive/MyDrive/day_night/Image00035.jpg', '/content/drive/MyDrive/day_night/Image00036.jpg', '/content/drive/MyDrive/day_night/Image00037.jpg', '/content/drive/MyDrive/day_night/Image00038.jpg', '/content/drive/MyDrive/day_night/Image00039.jpg', '/content/drive/MyDrive/day_night/Image00040.jpg', '/content/drive/MyDrive/day_night/Image00041.jpg', '/content/drive/MyDrive/day_night/Image00042.jpg', '/content/drive/MyDrive/day_night/Image00043.jpg', '/content/drive/MyDrive/day_night/Image00044.jpg', '/content/drive/MyDrive/day_night/Image00045.jpg', '/content/drive/MyDrive/day_night/Image00046.jpg', '/content/drive/MyDrive/day_night/Image00047.jpg', '/content/drive/MyDrive/day_night/Image00048.jpg', '/content/drive/MyDrive/day_night/Image00049.jpg', '/content/drive/MyDrive/day_night/Image00050.jpg', '/content/drive/MyDrive/day_night/Image00051.jpg', '/content/drive/MyDrive/day_night/Image00052.jpg', '/content/drive/MyDrive/day_night/Image00053.jpg', '/content/drive/MyDrive/day_night/Image00054.jpg', '/content/drive/MyDrive/day_night/Image00055.jpg', '/content/drive/MyDrive/day_night/Image00056.jpg', '/content/drive/MyDrive/day_night/Image00057.jpg', '/content/drive/MyDrive/day_night/Image00058.jpg', '/content/drive/MyDrive/day_night/Image00059.jpg', '/content/drive/MyDrive/day_night/Image00060.jpg', '/content/drive/MyDrive/day_night/Image00061.jpg', '/content/drive/MyDrive/day_night/Image00062.jpg', '/content/drive/MyDrive/day_night/Image00063.jpg', '/content/drive/MyDrive/day_night/Image00064.jpg', '/content/drive/MyDrive/day_night/Image00065.jpg', '/content/drive/MyDrive/day_night/Image00066.jpg', '/content/drive/MyDrive/day_night/Image00067.jpg', '/content/drive/MyDrive/day_night/Image00068.jpg', '/content/drive/MyDrive/day_night/Image00069.jpg', '/content/drive/MyDrive/day_night/Image00070.jpg', '/content/drive/MyDrive/day_night/Image00071.jpg', '/content/drive/MyDrive/day_night/Image00072.jpg', '/content/drive/MyDrive/day_night/Image00073.jpg', '/content/drive/MyDrive/day_night/Image00074.jpg', '/content/drive/MyDrive/day_night/Image00075.jpg', '/content/drive/MyDrive/day_night/Image00076.jpg', '/content/drive/MyDrive/day_night/Image00077.jpg', '/content/drive/MyDrive/day_night/Image00078.jpg', '/content/drive/MyDri ...

# %%
train_dataset = Dataset(train_dir , label_dir,256,1)
test_dataset = testDataset(test_dir)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:333: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "

# %%
test_dataset[1].shape
# Out:
# torch.Size([3, 384, 512])

# %%
pwd
# Out:
# '/content/drive/MyDrive'

# %%
origin_img = Image.open(f'/content/drive/MyDrive/night/01638325-504ab42d.jpg')
trans_img = train_dataset[1][0].numpy().transpose(1,2,0)
fix , ax = plt.subplots(ncols = 2,figsize = (8,8))
ax[0].set_title('before reduce')
ax[0].imshow(origin_img)
ax[1].set_title('after reduce')
ax[1].imshow(trans_img)
plt.show()

# %%
origin_img = Image.open(f'/content/drive/MyDrive/day/58610009-f3b500dd.jpg')
trans_img = train_dataset[0][1].numpy().transpose(1,2,0)
fix , ax = plt.subplots(ncols = 2,figsize = (8,8))
ax[0].set_title('before reduce')
ax[0].imshow(origin_img)
ax[1].set_title('after reduce')
ax[1].imshow(trans_img)
plt.show()

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size = 2,
    shuffle = True,
    num_workers=2
)

test_loader = DataLoader(
    test_dataset,
    batch_size = 1,
    shuffle = False
)

# %% [markdown]
# # 밤낮 전환 인공지능 모델 선정
#
#  개발 시 사용할 인공지능 신경망으로는 CNN을 선정
# 다른 신경망들과 다르게 이미지 데이터를 처리 할 때 이미지의 단순한 특징 뿐만 아니라 패턴까지 알아 낼 수 있는 장점이 있기 때문임
#
#  선정한 모델로는 Cycle Gan임
# - 사용할 데이터가 낮,밤에 대해서 같은 장소에 시간이 다른 paire된 데이터가 아니라 아예 개개인의 다른 장소의 낮 , 밤으로 이루어져 있기 때문에 unpaired된 image로 데이터의 특징을 전이할 수 있는 Cycle Gan을 이용한 현재 unpaired된 데이터로 특징을 전이 할 수 있는 모델은 Cycle Gan이 유일함

# %% [markdown]
# # generator

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.ReflectionPad2d(1), # reflectionpadding이란 가장자리 기준으로 input값을 패딩영역에 반전하여 복사하여 채우는 기법. 여기선 가장자리 1줄을 채움.
            nn.Conv2d(in_channels, in_channels, 3), #CNN.
            nn.InstanceNorm2d(in_channels), #BatchNorm과 다른 점은 Batch는 전체 Dataset기준으로 Batch를 Normalize하는 것이라면, Instance는 mini-Batch단위로 instance들을 Normalize한다는 점.
            nn.GELU(), # dropout, zoneout, ReLu 함수의 특성을 조합한 것이 GeLU, ReLU가 뛰어나긴 하나 음수가 되어버리면 그 때의 모든 기울기는 0이 되어버리기에 음수에서 조금의 기울기를 주는 형태.
            nn.ReflectionPad2d(1),
            nn.Conv2d(in_channels, in_channels, 3),
            nn.InstanceNorm2d(in_channels)
        )
    
    def forward(self, x):  # weight를 통과한 layer들과 통과하지 않은 값들을 더한 residual mapping방식. 
        return x + self.block(x) # x는 통과하지 않은 값들, self.block(x)는 통과한 값들.

# %%
class GeneratorResNet(nn.Module):
    def __init__(self, in_channels, num_residual_blocks=3):  # 이 클래스에서 resiudalblock 클래스를 이용할 때 쓰이는 변수. 현재는 layer 9번 쓴다고 선언 되어있고 block수는 맘대로 선언해도 됨.
        super(GeneratorResNet, self).__init__()
        
        out_channels=64   #최초의 convolution 블록. 처음 출력값은 64개.
        self.conv = nn.Sequential(
            nn.ReflectionPad2d(in_channels), 
            nn.Conv2d(in_channels, out_channels, 2*in_channels+1),# in_channels = 3 이유는 이미지는 모두 rgb를 가지고 있기 때문.
            nn.InstanceNorm2d(out_channels),
            nn.GELU(),
        )

        channels = out_channels # convolution 후 나온 값을 저장한 모습. 즉, 64가 저장 된다.
                                
                                # 이 작업으로 64개의 출력값을 가지고 있는 은닉층 형성.
        
        self.down = [] #데이터 수를 줄이는게 아니라 우리 빛번짐에서 이미지 축소하고 확장하잖아? 그중 축소하면서 특징 추출하는 과정임.
                       #generator는 기본적으로 Unet model을 기본으로 만들기 때문에 그 중 이미지 축소하면서 특징 추출하는거지
                       
        for _ in range(2): # 2번 반복하는데 index부분이 필요가 없으므로 _ 사용.
            out_channels = channels * 2 #채널 값을 2배로 늘린 후 저장(첫 컨볼루션에서 3-64 여기서 64-128, 그 후 128-256)
            self.down += [                                                  # 이미지 축소 과정.
                nn.Conv2d(channels, out_channels, 3, stride=2, padding=1),
                nn.InstanceNorm2d(out_channels),
                nn.GELU(),
            ]
            channels = out_channels # 각각의 출력값을 저장. 1번째 convolution에선 128. 2번째 convolution에선 256저장.
        self.down = nn.Sequential(*self.down) #위에 for문 과정 down 리스트에 저장.
        
        self.trans = [ResidualBlock(channels) for _ in range(num_residual_blocks)]  #residual block을 돌리는 코드.
                                                                                    # for문을 풀자면 ResidualBlock클래스를 9번 돌리고 그 결괏값을 trans에 저장한다는 코드.
                                                                                    
        self.trans = nn.Sequential(*self.trans) #trans라는 리스트에 resudial block 9개층을 저장(여기도 모델에 resudial block을 몇을 주냐에 따라 층 개수 달라짐)
        self.up = [] # residual block을 거쳐서 mapping이 진행된 값을 저장.
        
        for _ in range(2): #upsampling과정. 여기서는 이미지를 축소했기 때문에 다시 복원하는 과정이다.
            out_channels = channels // 2 # 컨볼루션 과정에서 3-64-128-256형태로 축소했기 때문에 다시 256-128-64-3형태로 가야한다.
                                         #여기서는 이미지를 다시 확장하는 과정임
            self.up += [
                nn.Upsample(scale_factor=2), # 이미지가 만약 2*2면 scale_factor = 2면 이미지가 4*4가 됨 이렇게 확장하는과정에서 빈공간의 수를 어떻게 채울지에 따라 3가지 방식 여기선 bil...어쩌고
                nn.Conv2d(channels, out_channels, 3, stride=1, padding=1), 
                nn.InstanceNorm2d(out_channels),
                nn.GELU(),
            ]
            channels = out_channels #위에 설명 해줬으니까 알겠지? / 다시 64를 저장.
        self.up = nn.Sequential(*self.up) #up list에 이미지 확장해주는 layer를 리스트로 저장
        
        self.out = nn.Sequential( #출력 layer. 이제 64-3 convolution 진행.
            nn.ReflectionPad2d(in_channels),
            nn.Conv2d(channels, in_channels, 2*in_channels+1),
            nn.Tanh() #마지막은 Sigmoid나 tanh둘중에 뭐쓸지 고민중 
        )
    
    def forward(self, x):
        x = self.conv(x)
        x = self.down(x)
        x = self.trans(x)
        x = self.up(x)
        x = self.out(x)
        return x

# %% [markdown]
# # discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, in_channels):
        super(Discriminator, self).__init__()
        
        self.model = nn.Sequential(
            *self.block(in_channels, 32, normalize=False),
            *self.block(32, 64),  
            *self.block(64, 128), 
            *self.block(128, 256),
            
            nn.ZeroPad2d((1,0,1,0)), 
            nn.Conv2d(256, 1, 4, padding=1)
        )
        
        self.scale_factor = 16
        self.m = nn.Sigmoid()
    
    @staticmethod
    def block(in_channels, out_channels, normalize=True):
        layers = [nn.Conv2d(in_channels, out_channels, 4, stride=2, padding=1)]
        if normalize:
            layers.append(nn.InstanceNorm2d(out_channels))
        layers.append(nn.LeakyReLU(0.2, inplace=True))
        
        return layers
        
    def forward(self, x):
        x = self.model(x)
        x = self.m(x)
        return x

# %%
G_AB = GeneratorResNet(3, num_residual_blocks=6)
D_B = Discriminator(3)

G_BA = GeneratorResNet(3, num_residual_blocks=6)
D_A = Discriminator(3)

# %%
criterion_GAN = nn.BCELoss()
criterion_cycle = nn.L1Loss()
criterion_identity = nn.MSELoss()

# %%
cuda = torch.cuda.is_available()
print(f'cuda: {cuda}')
if cuda:
    G_AB = G_AB.cuda()
    #G_AB.load_state_dict(torch.load('/content/drive/MyDrive/weight/'+'G_AB2.pt'))
    D_B = D_B.cuda()
    #D_B.load_state_dict(torch.load('/content/drive/MyDrive/weight/'+'D_B2.pt'))
    G_BA = G_BA.cuda()
    #G_BA.load_state_dict(torch.load('/content/drive/MyDrive/weight/'+'G_BA2.pt'))
    D_A = D_A.cuda()
    #D_A.load_state_dict(torch.load('/content/drive/MyDrive/weight/'+'D_A2.pt'))
    
    criterion_GAN = criterion_GAN.cuda()
    criterion_cycle = criterion_cycle.cuda()
    criterion_identity = criterion_identity.cuda()
# Out:
# cuda: True

# %% [markdown]
# # genrator 결과 시각화

# %%
from torchvision.utils import make_grid
import random
Tensor = torch.cuda.FloatTensor if cuda else torch.Tensor

def sample_images(real_A, figside=1.5):
    G_AB.cuda()
    G_AB.eval()
    G_BA.eval()
    
    real_A = real_A.type(Tensor) #진짜 밤 사진.
    fake_B = G_AB(real_A).detach()
    reconv_A = G_BA(fake_B).detach()
    '''
    real_B = real_B.type(Tensor)
    fake_A = G_BA(real_B).detach()
'''
    
    nrows = real_A.size(0)
    real_A = make_grid(real_A, nrow=nrows, normalize=True)
    fake_B = make_grid(fake_B, nrow=nrows, normalize=True)
    reconv_A = make_grid(reconv_A, nrow=nrows, normalize=True)
    #fake_A = make_grid(fake_A, nrow=nrows, normalize=True)
    
    image_grid = torch.cat((real_A, fake_B, reconv_A), 1).cpu().permute(1, 2, 0)
    
    plt.figure(figsize=(15, 10))
    plt.imshow(image_grid)
    plt.axis('off')
    plt.show()

# %%
real_A = next(iter(test_loader))
print(real_A.shape)
sample_images(real_A)
# Out:
# torch.Size([1, 3, 384, 512])

# %% [markdown]
# # 밤낮 전환 인공지능 인공지능 모델 학습
#
#
# Cycle Gan의 모델 구조는 이미지를 축소 -> 이미지 특징 전이 -> 특징이 전이 된 이미지를 확장 하는 순으로 진행이 된다
#
# 1번째로는 축소와 확장 횟수에 따른 결과 값을 비교하는 방식으로 진행하고
#
# 2번째로는 특징을 전이할 때 사용하는 신경망 층의 개수에 따른 성능을 비교해서
#
# 가장 좋았던 축소 확장 횟수 -> 가장 좋았던 특징 전이 신경망 층 개수 순으로 최종 인공지능 모델 구조를 선정한 후 최종 학습을 진행 할 예정

# %%
criterion_GAN = nn.BCELoss()
criterion_cycle = nn.L1Loss()
criterion_identity = nn.MSELoss()

# %%
import itertools
lr = 0.0002


optimizer_G = torch.optim.Adam(
    itertools.chain(G_AB.parameters(), G_BA.parameters()), lr=lr , betas = (0.5,0.999)
)

optimizer_D_A = torch.optim.Adam(
    D_A.parameters(), lr=lr , betas = (0.5,0.999)
)

optimizer_D_B = torch.optim.Adam(
    D_B.parameters(), lr=lr , betas = (0.5,0.999)
)

# %%
n_epoches = 300
decay_epoch = 20

lambda_func = lambda epoch: 1 - max(0, epoch-decay_epoch)/(n_epoches-decay_epoch)

lr_scheduler_G = torch.optim.lr_scheduler.LambdaLR(optimizer_G, lr_lambda=lambda_func)
lr_scheduler_D_A = torch.optim.lr_scheduler.LambdaLR(optimizer_D_A, lr_lambda=lambda_func)
lr_scheduler_D_B = torch.optim.lr_scheduler.LambdaLR(optimizer_D_B, lr_lambda=lambda_func)

# %%
'''
torch.manual_seed(777)

import gc
from tqdm.notebook import tqdm

for epoch in range(100):
    gc.collect()
    torch.cuda.empty_cache()

    for i, (real_A, real_B) in tqdm(enumerate(train_loader),total = len(train_loader)):
        real_A, real_B = real_A.type(Tensor), real_B.type(Tensor)
        
        # groud truth
        out_shape = [real_A.size(0), 1, real_A.size(2)//D_A.scale_factor, real_A.size(3)//D_A.scale_factor]
        valid = torch.ones(out_shape).type(Tensor)
        fake = torch.zeros(out_shape).type(Tensor)
        
        G_AB.train()
        G_BA.train()
        D_A.train()
        D_B.train()
        
        optimizer_G.zero_grad()
        
        fake_B = G_AB(real_A) 
        fake_A = G_BA(real_B)  
        
        loss_id_A = torch.sqrt(criterion_identity(fake_B, real_A)) 
        loss_id_B = torch.sqrt(criterion_identity(fake_A, real_B))
        loss_identity = (loss_id_A + loss_id_B) / 2

        loss_GAN_AB = criterion_GAN(D_B(fake_B),valid)
        loss_GAN_BA = criterion_GAN(D_A(fake_A), valid)
        loss_GAN = (loss_GAN_AB + loss_GAN_BA) / 2
        
        recov_A = G_BA(fake_B)
        recov_B = G_AB(fake_A)
        
        loss_cycle_A = criterion_cycle(recov_A, real_A)
        loss_cycle_B = criterion_cycle(recov_B, real_B)
        loss_cycle = (loss_cycle_A + loss_cycle_B) / 2
        
        loss_G = 5.0 *loss_identity + loss_GAN + 10.0*loss_cycle
        
        loss_G.backward()
        optimizer_G.step()
        
        optimizer_D_A.zero_grad()
        
        loss_real = criterion_GAN(D_A(real_A), valid)
        loss_fake = criterion_GAN(D_A(fake_A.detach()), fake)
        loss_D_A = (loss_real + loss_fake) / 2
        
        loss_D_A.backward()
        optimizer_D_A.step()
        
        optimizer_D_B.zero_grad()
        
        loss_real = criterion_GAN(D_B(real_B), valid)
        loss_fake = criterion_GAN(D_B(fake_B.detach()), fake)
        loss_D_B = (loss_real + loss_fake) / 2
        
        loss_D_B.backward()
        optimizer_D_B.step()
        
    
        torch.save(G_AB.state_dict(), '/content/drive/MyDrive/weight/'+f'G_AB{epoch+1}.pt') # model.load_state_dict(torch.load(G_AB2.pth))
        torch.save(G_BA.state_dict(), '/content/drive/MyDrive/weight/'+f'G_BA{epoch+1}.pt')
        torch.save(D_A.state_dict(), '/content/drive/MyDrive/weight/'+f'D_A{epoch+1}.pt')
        torch.save(D_B.state_dict(), '/content/drive/MyDrive/weight/'+f'D_B{epoch+1}.pt')
            
    lr_scheduler_G.step()
    lr_scheduler_D_A.step()
    lr_scheduler_D_B.step()
    
 
    test_real_A = next(iter(test_loader))
    if (epoch+1) % 5 == 0:
        sample_images(test_real_A)

    loss_D = (loss_D_A + loss_D_B) / 2
    if (epoch+1) % 10 == 0:
        print(f'[Epoch {epoch+1}/{n_epoches}]')
        print(f'[G loss: {loss_G.item()} | identity: {loss_identity.item()} GAN: {loss_GAN.item()} cycle: {loss_cycle.item()}]')
        print(f'[D loss: {loss_D.item()} | D_A: {loss_D_A.item()} D_B: {loss_D_B.item()}]') 
        
        '''
# Out:
# "\ntorch.manual_seed(777)\n\nimport gc\nfrom tqdm.notebook import tqdm\n\nfor epoch in range(100):\n    gc.collect()\n    torch.cuda.empty_cache()\n\n    for i, (real_A, real_B) in tqdm(enumerate(train_loader),total = len(train_loader)):\n        real_A, real_B = real_A.type(Tensor), real_B.type(Tensor)\n        \n        # groud truth\n        out_shape = [real_A.size(0), 1, real_A.size(2)//D_A.scale_factor, real_A.size(3)//D_A.scale_factor]\n        valid = torch.ones(out_shape).type(Tensor)\n        fake = torch.zeros(out_shape).type(Tensor)\n        \n        G_AB.train()\n        G_BA.train()\n        D_A.train()\n        D_B.train()\n        \n        optimizer_G.zero_grad()\n        \n        fake_B = G_AB(real_A) \n        fake_A = G_BA(real_B)  \n        \n        loss_id_A = torch.sqrt(criterion_identity(fake_B, real_A)) \n        loss_id_B = torch.sqrt(criterion_identity(fake_A, real_B))\n        loss_identity = (loss_id_A + loss_id_B) / 2\n\n        loss_GAN_AB = criterion_GAN(D_B(fake_B),valid)\n        loss_GAN_BA = criterion_GAN(D_A(fake_A), valid)\n        loss_GAN = (loss_GAN_AB + loss_GAN_BA) / 2\n        \n        recov_A = G_BA(fake_B)\n        recov_B = G_AB(fake_A)\n        \n        loss_cycle_A = criterion_cycle(recov_A, real_A)\n        loss_cycle_B = criterion_cycle(recov_B, real_B)\n        loss_cycle = (loss_cycle_A + loss_cycle_B) / 2\n        \n        loss_G = 5.0 *loss_identity + loss_GAN + 10.0*loss_cycle\n        \n        loss_G.backward()\n        optimizer_G.step()\n        \n        optimizer_D_A.zero_grad()\n        \n        loss_real = criterion_GAN(D_A(real_A), valid)\n        loss_fake = criterion_GAN(D_A(fake_A.detach()), fake)\n        loss_D_A = (loss_real + loss_fake) / 2\n        \n        loss_D_A.backward()\n        optimizer_D_A.step()\n        \n        optimizer_D_B.zero_grad()\n        \n        loss_real = criterion_GAN(D_B(real_B), valid)\n        loss_fake = criterion_GAN(D_B(fake_B.detach()), fake)\n        loss_D_B = (loss_real + loss_fake) / 2\n        \n        loss_D_B.backward()\n        optimizer_D_B.step()\n        \n    \n        torch.save(G_AB.state_dict(), '/content/drive/MyDrive/weight/'+f'G_AB{epoch+1}.pt') # model.load_state_dict(torch.load(G_AB2.pth))\n        torch.save(G_BA.state_dict(), '/content/drive/MyDrive/weight/'+f'G_BA{epoch+1}.pt')\n        torch.save(D_A.state_dict(), '/content/drive/MyDrive/weight/'+f'D_A{epoch+1}.pt')\n        torch.save(D_B.state_dict(), '/content/drive/MyDrive/weight/'+f'D_B{epoch+1}.pt')\n            \n    lr_scheduler_G.step()\n    lr_scheduler_D_A.step()\n    lr_scheduler_D_B.step()\n    \n \n    test_real_A = next(iter(test_loader))\n    if (epoch+1) % 5 == 0:\n        sample_images(test_real_A)\n\n    loss_D = (loss_D_A + loss_D_B) / 2\n    if (epoch+1) % 10 == 0:\n        print(f'[Epoch {epoch+1}/{n_epoches}]')\n        print(f'[G loss: {loss_G.item()} | identity: {loss_identity.item()} GAN: {loss_GAN.item()} cycle: {loss_cycle.item()}]')\n        print(f'[D loss: {loss_D.item()} | D_A: {loss_D_A.item()} D_B: {loss_D_B.item()}]') \n        \n        "

# %%
# !nvidia-smi
# Out:
# Thu Jun  9 09:49:57 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    26W /  70W |   2580MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # 밤낮 인공지능 검증

# %%
real_A= next(iter(test_loader))
print(real_A.shape)

sample_images(real_A)
# Out:
# torch.Size([1, 3, 384, 512])

# %% [markdown]
# # 전체 결과 보기(빛 줄인 후 밤낮 전환)

# %%
'''
import time
from IPython import display
model.eval()
G_AB.eval()
model.load_state_dict(torch.load('/content/drive/MyDrive/weight/efficientnet.pt'))
G_AB.load_state_dict(torch.load('/content/drive/MyDrive/weight/밤.pt'))
idx=0
with torch.no_grad():
    for data in test_loader:
      predict = model(data.to(device))  
      pred = G_AB(predict.to(device))
      fix , ax = plt.subplots(ncols = 3,figsize = (20,15))
      ax[0].set_title('input(vaildation)')
      ax[0].imshow(np.moveaxis(data.reshape(3,384,512).cpu().numpy(),0,2))
      ax[1].set_title('reduce light')
      ax[1].imshow(np.moveaxis(predict.reshape(3,384,512).cpu().numpy(),0,2))
      ax[2].set_title('transform to day')
      ax[2].imshow(np.moveaxis(pred.reshape(3,384,512).cpu().numpy(),0,2))

   
      idx = idx+1
      print(idx)
      display.clear_output(wait=True)
      plt.show()
      #time.sleep(2)
    #print(image.shape , output.shape ,out.shape)
     '''
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-ad3edc343463> in <module>()
#      22       print(idx)
#      23       display.clear_output(wait=True)
# ---> 24       plt.show()
#      25       #time.sleep(2)
#      26     #print(image.shape , output.shape ,out.shape)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
#     304             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     305         else:
# --> 306             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     307             if not format_dict:
#     308                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     171             md = None
#     172             try:
# --> 173                 data = formatter(obj)
#     174             except:
#     175                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     215     """show traceback on failed format call"""
#     216     try:
# --> 217         r = method(self, *args, **kwargs)
#     218     except NotImplementedError:
#     219         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2124                     orientation=orientation,
#    2125                     bbox_inches_restore=_bbox_inches_restore,
# -> 2126                     **kwargs)
#    2127             finally:
#    2128                 if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
# --> 537                                metadata={**default_metadata, **metadata})
#     538
#     539     def print_to_buffer(self):
#
# KeyboardInterrupt:

# %%
import time
from IPython import display
'''
model.eval()
G_AB.eval()
model.load_state_dict(torch.load('/content/drive/MyDrive/weight/efficientnet.pt'))
G_AB.load_state_dict(torch.load('/content/drive/MyDrive/weight/밤.pt'))
with torch.no_grad():
    idx=0
    for data  in test_loader:
        data = data
        predict = model(data.to(device))  
        pred = G_AB(predict.to(device))
        fix , ax = plt.subplots(ncols = 3,figsize = (20,15))
        ax[0].set_title('input(vaildation)')
        ax[0].imshow(np.moveaxis(data.reshape(3,384,512).cpu().numpy(),0,2))
        ax[1].set_title('reduce light')
        ax[1].imshow(np.moveaxis(predict.reshape(3,384,512).cpu().numpy(),0,2))
        ax[2].set_title('transform to day')
        ax[2].imshow(np.moveaxis(pred.reshape(3,384,512).cpu().numpy(),0,2))

        display.clear_output(wait=True)
        idx = idx+1
        print(idx)
        plt.show()
        
        #display.clear_output(wait=True)
        #time.sleep(1)
        #print(image.shape , output.shape ,out.shape)
        '''
# Out:
# 38

# %% [markdown]
# # 전체 결과 보기(밤낮 전환 후 빛 줄이기)

# %%
import time
from IPython import display
model.eval()
G_AB.eval()
model.load_state_dict(torch.load('/content/drive/MyDrive/weight/efficientnet.pt'))
G_AB.load_state_dict(torch.load('/content/drive/MyDrive/weight/밤.pt'))
with torch.no_grad():
    for image  in test_loader:
        image = image
        output = G_AB(image.to(device))  
        out = model(output.to(device))
        print(image.shape , output.shape ,out.shape)
        fix , ax = plt.subplots(ncols = 3,figsize = (20,15))
        ax[0].set_title('input(vaildation)')
        ax[0].imshow(np.moveaxis(image.reshape(3,384,512).cpu().numpy(),0,2))
        ax[1].set_title('transform to day')
        ax[1].imshow(np.moveaxis(output.reshape(3,384,512).cpu().numpy(),0,2))
        ax[2].set_title('reduce light')
        ax[2].imshow(np.moveaxis(out.reshape(3,384,512).cpu().numpy(),0,2))

# %% [markdown]
# # 그냥 밤낮만 전환 했을 때랑 빛 최소화 후 밤낮 전환 했을 때랑 밤낮 전환 후 빛 최소화를 비교

# %%
import time
from IPython import display

model.eval()
G_AB.eval()
model.load_state_dict(torch.load('/content/drive/MyDrive/weight/efficientnet.pt'))
G_AB.load_state_dict(torch.load('/content/drive/MyDrive/weight/밤.pt'))
with torch.no_grad():
    idx=0

    for image in test_loader:

        
        image = image
        reduce_image = model(image.to(device))  
        nd_image = G_AB(image.to(device))
        predict = G_AB(reduce_image.to(device))
        prediction = model(nd_image.to(device))
        fix , ax = plt.subplots(ncols = 4,figsize = (15,8))
        ax[0].set_title('input(vaildation)')
        ax[0].imshow(np.moveaxis(image.reshape(3,384,512).cpu().numpy(),0,2))
        ax[1].set_title('only transform night to day')
        ax[1].imshow(np.moveaxis(nd_image.reshape(3,384,512).cpu().detach().numpy(),0,2))
        ax[2].set_title('reduce light and transform night to day')
        ax[2].imshow(np.moveaxis(predict.reshape(3,384,512).cpu().detach().numpy(),0,2))
        ax[3].set_title('transform night to day and reduce light')
        ax[3].imshow(np.moveaxis(prediction.reshape(3,384,512).cpu().detach().numpy(),0,2))

        display.clear_output(wait=True)
        idx = idx+1
        print(idx)
        plt.show()
        time.sleep(1.5)
# Out:
# 119
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-eb76f5afb4de> in <module>()
#      31         print(idx)
#      32         plt.show()
# ---> 33         time.sleep(1.5)
#      34
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import cv2


# 컬러 영상 출력
imgBGR = cv2.imread('/content/drive/MyDrive/전방1/블랙박스.mp4')
imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB) #RGB 오더링으로 변경

plt.axis('off')
plt.imshow(imgRGB)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-88-37c58a1e13e6> in <module>()
#       5 # 컬러 영상 출력
#       6 imgBGR = cv2.imread('/content/drive/MyDrive/전방1/블랙박스.mp4')
# ----> 7 imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB) #RGB 오더링으로 변경
#       8
#       9 plt.axis('off')
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
